# %% [markdown]
# <img src="https://github.com/hernancontigiani/ceia_memorias_especializacion/raw/master/Figures/logoFIUBA.jpg" width="500" align="center">
#
#
# # Procesamiento de lenguaje natural
# ## Modelo de lenguaje con tokenización por palabras

# %% [markdown]
# ### Consigna
# - Seleccionar un corpus de texto sobre el cual entrenar el modelo de lenguaje.
# - Realizar el pre-procesamiento adecuado para tokenizar el corpus, estructurar el dataset y separar entre datos de entrenamiento y validación.
# - Proponer arquitecturas de redes neuronales basadas en unidades recurrentes para implementar un modelo de lenguaje.
# - Con el o los modelos que consideren adecuados, generar nuevas secuencias a partir de secuencias de contexto con las estrategias de greedy search y beam search determístico y estocástico. En este último caso observar el efecto de la temperatura en la generación de secuencias.
#
#
# ### Sugerencias
# - Durante el entrenamiento, guiarse por el descenso de la perplejidad en los datos de validación para finalizar el entrenamiento. Para ello se provee un callback.
# - Explorar utilizar SimpleRNN (celda de Elman), LSTM y GRU.
# - rmsprop es el optimizador recomendado para la buena convergencia. No obstante se pueden explorar otros.

# %%
import random
import io
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras import layers
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %% [markdown]
# ### Datos
# Como ejemplo se utilizará como corpus un dataset canciones de bandas de habla inglés.

# %%
# Leer el archivo CSV
url = 'https://raw.githubusercontent.com/sevann-radhak/procesamiento_lenguaje_natural/main/clase_2/ejercicios/raw/True.csv'
df = pd.read_csv(url)

# %% [markdown]
# Consideraremos que cada secuencia para este dataset es un verso.
#
# Una de las primeras decisiones que hay que tomar es el tamaño de contexto de tokens máximo que puede consumir el modelo. Este podría ser un hiperparámetro del problema.
#
# Para elegir el tamaño de contexto máximo para este problema se puede explorar el dataset, para ello:
# - se consideran las palabras como términos.
# - se segmentará el texto de todos los versos del dataset y ses explorará la cantidad de términos presentes.

# %%
print("Cantidad de documentos:", df.shape[0])
# Out:
# Cantidad de documentos: 21417

# %%
# Trabajar solo con 1000 documentos y la columna 'title'
df = df[['title']].sample(n=2000, random_state=42)

print("Cantidad de documentos:", df.shape[0])
# Out:
# Cantidad de documentos: 2000

# %% [markdown]
# ### Elegir el tamaño del contexto

# %%
# Usaremos las utilidades de procesamiento de textos y secuencias de Keras
from tensorflow.keras.preprocessing.text import Tokenizer # equivalente a ltokenizer de nltk
from tensorflow.keras.preprocessing.text import text_to_word_sequence # equivalente a word_tokenize de nltk
from tensorflow.keras.utils import pad_sequences # se utilizará para padding

# %%
# cada title lo guardamos en una lista
text = df['title'].tolist()

# %%
# Ver algunos ejemplos
print(text[:2])
# Out:
# ["Europe rights watchdog says Turkey's emergency laws go too far", 'Exclusive: Trump targets illegal immigrants who were given reprieves from deportation by Obama']

# %%
# segmentamos el texto con la utilidad de Keras
segmented_sentences = [text_to_word_sequence(sentence) for sentence in text]

# %%
text[0]
# Out:
# "Europe rights watchdog says Turkey's emergency laws go too far"

# %%
segmented_sentences[0]
# Out:
# ['europe',
#  'rights',
#  'watchdog',
#  'says',
#  "turkey's",
#  'emergency',
#  'laws',
#  'go',
#  'too',
#  'far']

# %%
# calculamos la longitud de cada secuencia
length_sentences = [len(sentence) for sentence in segmented_sentences]

# %%
# podemos ver su distribución
plt.hist(length_sentences,bins=20)
# Out:
# (array([  4.,  16.,   0.,  65., 173.,   0., 364., 470.,   0., 383., 284.,
#           0., 137.,  80.,   0.,  15.,   7.,   0.,   1.,   1.]),
#  array([ 5.  ,  5.65,  6.3 ,  6.95,  7.6 ,  8.25,  8.9 ,  9.55, 10.2 ,
#         10.85, 11.5 , 12.15, 12.8 , 13.45, 14.1 , 14.75, 15.4 , 16.05,
#         16.7 , 17.35, 18.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# **Nota:** Dado el histograma de la distribución de longitudes de secuencias, parece que una gran parte de las secuencias tiene una longitud entre 5 y 12 palabras, con muy pocas secuencias más largas. Para asegurar que nuestro modelo sea eficiente y capture la mayoría de las secuencias sin incluir demasiado padding, podemos usar la mediana como criterio para definir el tamaño máximo del contexto.

# %%
# a partir de la distribución de longitudes de secuencias elegimos algún criterio
# para determinar el máximo tamaño de contexto. En este caso es un percentil, pero
# otros criterios también pueden ser válidos con la justificación adecuada.
# También puede ser una selección "a mano"

# el -1 es porque el último token será el target
max_context_size = int(np.ceil(np.median(length_sentences)) - 1)

print(f'max_context_size: {max_context_size}')
# Out:
# max_context_size: 9

# %% [markdown]
# ###  Tokenizar

# %%
# instanciamos el tokenizador
tok = Tokenizer()

# El tokenizer "aprende" las palabras que se usaran
# Se construye (fit) una vez por proyecto, se aplica N veces (tal cual un encoder)
# El token 0 es reservado y no es asignado. Se utiliza para designar a palabras
# fuera del vocabulario aprendido
tok.fit_on_texts(segmented_sentences)

# Convertimos las palabras a números
# entran palabras -> salen números
tokenized_sentences = tok.texts_to_sequences(segmented_sentences)

# %%
tokenized_sentences[0]
# Out:
# [1079, 85, 466, 7, 650, 819, 2201, 296, 1080, 263]

# %%
segmented_sentences[0]
# Out:
# ['europe',
#  'rights',
#  'watchdog',
#  'says',
#  "turkey's",
#  'emergency',
#  'laws',
#  'go',
#  'too',
#  'far']

# %% [markdown]
# ### Organizando y estructurando el dataset

# %% [markdown]
# En este punto tenemos en la variable `tokenized_sentences` los versos tokenizados. Vamos a quedarnos con un conjunto de validación que utilizaremos para medir la calidad de la generación de secuencias con la métrica de Perplejidad.

# %%
tokenized_sentences_train, tokenized_sentences_val, _, _ = train_test_split(tokenized_sentences, tokenized_sentences, test_size=0.2, random_state=42)

# %% [markdown]
# \Vamos a splitear las oraciones que tienen tamaño mayor al contexto máximo, para generarnos más secuencias de entrenamiento. Este paso puede obviarse si el tamaño de contexto máximo es muy grande.
#
# Por ejemplo, si tenemos el texto *La bella y graciosa moza marchóse a lavar la ropa* y nuestro contexto es de 5 palabras, tendremos:
#
# - *La bella y graciosa moza*
# - *bella y graciosa moza marchóse*
# - *y graciosa moza marchóse a*
# - *graciosa moza marchóse a lavar*
# - *moza marchóse a lavar la*
# - *marchóse a lavar la ropa*

# %%
tok_sent = []

for sent in tokenized_sentences_train:

  # si la secuencia tiene más términos que el tamaño de contexto máximo,
  # armo varias sub-secuencias de tamaño máximo
  if len(sent) > (max_context_size+1):
    extra = len(sent)-(max_context_size+1) + 1
    for i in range(extra):
      tok_sent.append(sent[i:i+max_context_size+1])
  else: # si la secuencia tiene menos términos el tamaño de contexto máximo, dejo la secuencia como está
    tok_sent.append(sent)

# %%
len(tok_sent)
# Out:
# 3064

# %% [markdown]
# Ahora aumentamos los datos aprovechando que de una secuencia grande se pueden generar varias más pequeñas:
#
# - *La hermosa casa en el prado*
# - *La hermosa*
# - *La hermosa casa*
# - *La hermosa casa en*
# - *La hermosa casa en el*
# - *La hermosa casa en el prado*

# %%
tok_sent_augm = []

for sent in tok_sent:

  # generamos todas las sub-secuencias
  subseq = [sent[:i+2] for i in range(len(sent)-1)]
  # en esta línea paddeamos al tamaño de contexto máximo
  tok_sent_augm.append(pad_sequences(subseq, maxlen=max_context_size+1, padding='pre'))

# %%
# finalmente concatenamos todas las secuencias en un único array de numpy
train_seqs = np.concatenate(tok_sent_augm, axis=0)

# %%
train_seqs.shape
# Out:
# (26768, 10)

# %%
# y de aquí sacamos las entradas y los targets que consumirá nuestro sistema en
# tiempo de entrenamiento
X = train_seqs[:,:-1]
y = train_seqs[:,1:]

# %% [markdown]
# Nótese que estamos estructurando el problema de aprendizaje como *many-to-many*:
#
# Entrada: secuencia de tokens [$x_0$, $x_1$, ..., $x_N$]
#
# Target: secuencia de tokens [$x_1$, $x_2$, ..., $x_{N+1}$]
#
# De manera que la red tiene que aprender que su salida deben ser los tokens desplazados en una posición y un nuevo token predicho (el N+1).
#
# La ventaja de estructurar el aprendizaje de esta manera es que para cada token de target se propaga una señal de gradiente por el grafo de cómputo recurrente, que es mejor que estructurar el problema como *many-to-one* en donde sólo una señal de gradiente se propaga.

# %%
y.shape
# Out:
# (26768, 9)

# %%
# Palabras del vocabulario
tok.index_word
# Out:
# {1: 'to',
#  2: 'trump',
#  3: 'u',
#  4: 'in',
#  5: 's',
#  6: 'on',
#  7: 'says',
#  8: 'of',
#  9: 'for',
#  10: 'with',
#  11: 'house',
#  12: 'as',
#  13: 'over',
#  14: 'after',
#  15: 'north',
#  16: 'not',
#  17: 'new',
#  18: 'russia',
#  19: 'korea',
#  20: 'at',
#  21: 'from',
#  22: 'state',
#  23: 'white',
#  24: "trump's",
#  25: 'senate',
#  26: 'will',
#  27: 'obama',
#  28: 'court',
#  29: 'by',
#  30: 'vote',
#  31: 'and',
#  32: 'china',
#  33: 'n',
#  34: 'tax',
#  35: 'republican',
#  36: 'bill',
#  37: 'eu',
#  38: 'deal',
#  39: 'be',
#  40: 'iran',
#  41: 'president',
#  42: 'a',
#  43: 'clinton',
#  44: 'factbox',
#  45: 'south',
#  46: 'brexit',
#  47: 'chief',
#  48: 'sanctions',
#  49: 'minister',
#  50: 'the',
#  51: 'may',
#  52: 'election',
#  53: 'republicans',
#  54: 'russian',
#  55: 'talks',
#  56: 'pm',
#  57: 'against',
#  58: 'ex',
#  59: 'turkey',
#  60: 'saudi',
#  61: 'meet',
#  62: 'is',
#  63: 'no',
#  64: 'calls',
#  65: 'government',
#  66: 'congress',
#  67: 'military',
#  68: 'official',
#  69: 'more',
#  70: 'putin',
#  71: 'police',
#  72: 'security',
#  73: 'syria',
#  74: 'nuclear',
#  75: 'out',
#  76: 'probe',
#  77: 'budget',
#  78: 'defense',
#  79: 'islamic',
#  80: 'general',
#  81: 'attack',
#  82: 'lawmakers',
#  83: 'plan',
#  84: 'trade',
#  85: 'rights',
#  86: 'leader',
#  87: 'german',
#  88: 'up',
#  89: 'law',
#  90: 'into',
#  91: 'party',
#  92: 'supreme',
#  93: 'anti',
#  94: 'urges',
#  95: 'healthcare',
#  96: 'panel',
#  97: 'governor',
#  98: 'foreign',
#  99: 'border',
#  100: 'travel',
#  101: 'ban',
#  102: 'it',
#  103: 'opposition',
#  104: 'could',
#  105: 'top',
#  106: 'two',
#  107: 'tells',
#  108: 'first',
#  109: 'democrats',
#  110: 'campaign',
#  111: 'coalition',
#  112: 'speaker',
#  113: 'myanmar',
#  114: 'discuss',
#  115: 'about',
#  116: 'tillerson',
#  117: 'meeting',
#  118: 'war',
#  119: 'million',
#  120: 'britain',
#  121: 'mexico',
#  122: 'iraqi',
#  123: 'ties',
#  124: 'jerusalem',
#  125: 'sources',
#  126: 'seeks',
#  127: 'crisis',
#  128: 'policy',
#  129: 'ruling',
#  130: 'presidential',
#  131: 'senator',
#  132: 'next',
#  133: 'week',
#  134: 'if',
#  135: 'his',
#  136: 'missile',
#  137: 'attorney',
#  138: 'amid',
#  139: 'nominee',
#  140: 'kurdish',
#  141: 'air',
#  142: 'has',
#  143: 'move',
#  144: 'should',
#  145: 'killed',
#  146: 'forces',
#  147: 'but',
#  148: 'ready',
#  149: 'off',
#  150: 'exclusive',
#  151: 'wants',
#  152: 'warns',
#  153: 'one',
#  154: 'would',
#  155: 'former',
#  156: 'reform',
#  157: 'senators',
#  158: 'visit',
#  159: 'israel',
#  160: 'support',
#  161: 'uk',
#  162: 'twitter',
#  163: 'aid',
#  164: 'case',
#  165: 'take',
#  166: 'end',
#  167: 'he',
#  168: 'officials',
#  169: 'fbi',
#  170: 'merkel',
#  171: 'leaders',
#  172: 'administration',
#  173: 'right',
#  174: 'ryan',
#  175: 'rohingya',
#  176: 'iraq',
#  177: 'army',
#  178: 'force',
#  179: 'test',
#  180: 'kremlin',
#  181: 'media',
#  182: 'catalan',
#  183: 'must',
#  184: 'secretary',
#  185: 'judge',
#  186: 'seek',
#  187: 'threat',
#  188: 'kill',
#  189: 'possible',
#  190: 'make',
#  191: 'department',
#  192: 'back',
#  193: 'approves',
#  194: 'call',
#  195: 'before',
#  196: 'four',
#  197: 'bid',
#  198: 'trial',
#  199: 'open',
#  200: 'obamacare',
#  201: 'catalonia',
#  202: 'ahead',
#  203: 'sees',
#  204: 'kills',
#  205: 'race',
#  206: 'comments',
#  207: 'comey',
#  208: 'korean',
#  209: 'syrian',
#  210: 'help',
#  211: 'pick',
#  212: 'immigration',
#  213: 'rally',
#  214: 'decision',
#  215: 'health',
#  216: 'macron',
#  217: 'states',
#  218: 'parliament',
#  219: 'run',
#  220: 'aide',
#  221: 'flynn',
#  222: 'puerto',
#  223: 'rico',
#  224: 'does',
#  225: 'statement',
#  226: 'three',
#  227: 'fight',
#  228: 'action',
#  229: 'key',
#  230: 'set',
#  231: 'political',
#  232: 'who',
#  233: 'summit',
#  234: 'york',
#  235: 'presidency',
#  236: 'lead',
#  237: 'reuters',
#  238: 'agencies',
#  239: 'dead',
#  240: 'asks',
#  241: 'rules',
#  242: 'washington',
#  243: 'turkish',
#  244: 'than',
#  245: 'democratic',
#  246: 'backs',
#  247: 'reports',
#  248: '1',
#  249: 'source',
#  250: 'climate',
#  251: "china's",
#  252: 'xi',
#  253: 'japan',
#  254: 'group',
#  255: 'committee',
#  256: 'capital',
#  257: 'rule',
#  258: 'jobs',
#  259: 'debate',
#  260: 'oil',
#  261: 'arrested',
#  262: 'say',
#  263: 'far',
#  264: 'legal',
#  265: 'expects',
#  266: 'issues',
#  267: 'france',
#  268: 'poll',
#  269: 'control',
#  270: 'protests',
#  271: 'march',
#  272: 'germany',
#  273: 'independence',
#  274: 'that',
#  275: 'chair',
#  276: 'this',
#  277: 'adviser',
#  278: 'people',
#  279: 'post',
#  280: 'arabia',
#  281: 'erdogan',
#  282: 'latest',
#  283: 'agency',
#  284: 'sessions',
#  285: 'zimbabwe',
#  286: 'report',
#  287: 'corruption',
#  288: 'egypt',
#  289: 'still',
#  290: 'lawmaker',
#  291: 'northern',
#  292: 'order',
#  293: 'close',
#  294: 'intelligence',
#  295: 'plans',
#  296: 'go',
#  297: 'graft',
#  298: 'most',
#  299: 'stay',
#  300: 'avoid',
#  301: 'role',
#  302: 'highlights',
#  303: '6',
#  304: 'push',
#  305: 'urge',
#  306: 'see',
#  307: 'get',
#  308: 'year',
#  309: 'vows',
#  310: 'cut',
#  311: 'wins',
#  312: 'attacks',
#  313: 'special',
#  314: 'its',
#  315: 'near',
#  316: '15',
#  317: 'mccain',
#  318: 'him',
#  319: 'soldiers',
#  320: 'likely',
#  321: 'ria',
#  322: 'head',
#  323: 'epa',
#  324: 'offers',
#  325: 'friday',
#  326: 'lawyer',
#  327: 'cuba',
#  328: 'cruz',
#  329: 'spy',
#  330: 'hold',
#  331: 'embassy',
#  332: 'venezuela',
#  333: 'envoy',
#  334: 'mugabe',
#  335: "russia's",
#  336: 'lebanon',
#  337: 'release',
#  338: 'spanish',
#  339: 'votes',
#  340: 'cnn',
#  341: 'picks',
#  342: 'elections',
#  343: "germany's",
#  344: 'major',
#  345: 'gun',
#  346: 'p',
#  347: 'm',
#  348: 'strike',
#  349: 'peace',
#  350: 'business',
#  351: 'violence',
#  352: 'strikes',
#  353: 'spokesman',
#  354: 'migrants',
#  355: 'meets',
#  356: 'death',
#  357: 'was',
#  358: 'chinese',
#  359: 'pakistan',
#  360: 'illinois',
#  361: 'five',
#  362: 'sanders',
#  363: 'all',
#  364: 'years',
#  365: 'irma',
#  366: 'senior',
#  367: 'ukraine',
#  368: 'mcconnell',
#  369: 'other',
#  370: 'french',
#  371: "zimbabwe's",
#  372: 'bank',
#  373: 'world',
#  374: 'blast',
#  375: 'hit',
#  376: 'backed',
#  377: 'ireland',
#  378: 'region',
#  379: 'kirkuk',
#  380: 'response',
#  381: 'stability',
#  382: 'least',
#  383: 'east',
#  384: 'review',
#  385: 'british',
#  386: 'women',
#  387: 'face',
#  388: 'cuts',
#  389: 'testify',
#  390: 'hariri',
#  391: 'orders',
#  392: "'",
#  393: 'mayor',
#  394: 'billion',
#  395: 'seen',
#  396: 'vietnam',
#  397: 're',
#  398: 'indonesian',
#  399: 'can',
#  400: 'wednesday',
#  401: 'without',
#  402: "eu's",
#  403: 'april',
#  404: 'michigan',
#  405: 'flint',
#  406: 'ipsos',
#  407: 'working',
#  408: 'funding',
#  409: 'moscow',
#  410: 'national',
#  411: 'taiwan',
#  412: 'al',
#  413: 'claims',
#  414: 'effort',
#  415: 'australia',
#  416: '9',
#  417: 'ambassador',
#  418: 'use',
#  419: 'democrat',
#  420: 'or',
#  421: 'referendum',
#  422: 'thursday',
#  423: 'prosecutor',
#  424: 'how',
#  425: 'unlikely',
#  426: 'have',
#  427: 'voter',
#  428: 'arms',
#  429: 'power',
#  430: 'son',
#  431: 'tuesday',
#  432: 'facebook',
#  433: 'ask',
#  434: 'change',
#  435: 'opens',
#  436: 'another',
#  437: 'sign',
#  438: 'long',
#  439: 'justice',
#  440: 'suspected',
#  441: 'yemen',
#  442: '2017',
#  443: 'are',
#  444: 'time',
#  445: 'activists',
#  446: "korea's",
#  447: 'king',
#  448: 'passes',
#  449: 'johnson',
#  450: 'raises',
#  451: 'win',
#  452: 'cyber',
#  453: 'day',
#  454: 'director',
#  455: 'wife',
#  456: 'regional',
#  457: 'bomb',
#  458: 'future',
#  459: 'offer',
#  460: 'rejects',
#  461: '2018',
#  462: 'pence',
#  463: 'city',
#  464: 'energy',
#  465: 'ceo',
#  466: 'watchdog',
#  467: 'leave',
#  468: 'list',
#  469: 'challenge',
#  470: 'blow',
#  471: '2',
#  472: "africa's",
#  473: 'california',
#  474: 'percent',
#  475: "may's",
#  476: 'job',
#  477: 'stop',
#  478: 'making',
#  479: 'request',
#  480: 'allies',
#  481: 'car',
#  482: 'family',
#  483: 'act',
#  484: 'soon',
#  485: 'corporate',
#  486: 'paris',
#  487: 'texas',
#  488: 'hopes',
#  489: 'global',
#  490: 'sale',
#  491: 'florida',
#  492: 'freedom',
#  493: 'migrant',
#  494: 'policies',
#  495: 'return',
#  496: 'protesters',
#  497: 'arrest',
#  498: 'sudan',
#  499: 'nine',
#  500: 'debt',
#  501: 'kurds',
#  502: 'czech',
#  503: 'woman',
#  504: 'wall',
#  505: 'faces',
#  506: 'under',
#  507: 'did',
#  508: 'linked',
#  509: 'qatar',
#  510: 'gas',
#  511: 'asked',
#  512: "britain's",
#  513: '5',
#  514: 'days',
#  515: 'united',
#  516: 'behind',
#  517: 'signs',
#  518: 'afghanistan',
#  519: '11',
#  520: 'bush',
#  521: 'join',
#  522: 'led',
#  523: 'airport',
#  524: 'agenda',
#  525: 'market',
#  526: 'spain',
#  527: 'african',
#  528: 'kurdistan',
#  529: 'need',
#  530: 'returns',
#  531: '000',
#  532: 'pentagon',
#  533: 'labor',
#  534: 'an',
#  535: 'makes',
#  536: 'fed',
#  537: 'some',
#  538: 'man',
#  539: 'rebels',
#  540: 'despite',
#  541: 'refugee',
#  542: 'scandal',
#  543: 'accused',
#  544: 'hurricane',
#  545: 'visa',
#  546: 'fraud',
#  547: 'voters',
#  548: 'targets',
#  549: 'edt',
#  550: '13',
#  551: 'care',
#  552: 'eye',
#  553: 'many',
#  554: 'aims',
#  555: 'mnuchin',
#  556: 'treasury',
#  557: 'terrorism',
#  558: 'money',
#  559: 'federal',
#  560: 'keep',
#  561: 'vice',
#  562: 'americans',
#  563: 'team',
#  564: 'nafta',
#  565: 'water',
#  566: 'times',
#  567: 'details',
#  568: 'somalia',
#  569: 'running',
#  570: 'presses',
#  571: 'gets',
#  572: "iran's",
#  573: 'pact',
#  574: 'human',
#  575: 'watch',
#  576: 'conference',
#  577: 'efforts',
#  578: 'term',
#  579: 'canada',
#  580: 'medical',
#  581: 'mid',
#  582: "don't",
#  583: 'asylum',
#  584: 'among',
#  585: 'parties',
#  586: 'israeli',
#  587: 'visits',
#  588: 'sea',
#  589: 'militants',
#  590: "egypt's",
#  591: "won't",
#  592: 'pay',
#  593: 'last',
#  594: 'strong',
#  595: 'confirms',
#  596: 'refugees',
#  597: 'find',
#  598: 'hearing',
#  599: 'start',
#  600: "france's",
#  601: 'between',
#  602: 'gives',
#  603: 'allegations',
#  604: 'aim',
#  605: 'july',
#  606: 'takes',
#  607: 'yet',
#  608: 'prime',
#  609: 'george',
#  610: 'threatens',
#  611: 'decide',
#  612: 'accounts',
#  613: 'activist',
#  614: 'prison',
#  615: "lebanon's",
#  616: 'arrests',
#  617: 'workers',
#  618: 'taxes',
#  619: 'her',
#  620: 'palestinian',
#  621: 'supports',
#  622: 'needed',
#  623: 'mexican',
#  624: 'early',
#  625: 'august',
#  626: 'japanese',
#  627: 'talk',
#  628: 'month',
#  629: 'transgender',
#  630: 'block',
#  631: 'india',
#  632: "iraq's",
#  633: 'letter',
#  634: 'public',
#  635: '100',
#  636: 'situation',
#  637: 'pass',
#  638: 'congressional',
#  639: '25',
#  640: 'muslims',
#  641: 'groups',
#  642: 'dutch',
#  643: 'battle',
#  644: 'reforms',
#  645: "uk's",
#  646: 'diplomat',
#  647: 'irish',
#  648: 'investment',
#  649: "treasury's",
#  650: "turkey's",
#  651: 'christie',
#  652: 'investigation',
#  653: 'boeing',
#  654: 'tusk',
#  655: 'limit',
#  656: 'hawaii',
#  657: 'co',
#  658: 'schools',
#  659: 'charges',
#  660: 'points',
#  661: 'steps',
#  662: 'criticism',
#  663: 'leadership',
#  664: 'defends',
#  665: 'speech',
#  666: 'turn',
#  667: 'search',
#  668: 'fuel',
#  669: 'want',
#  670: 'nominate',
#  671: 'abortion',
#  672: '20',
#  673: 'trying',
#  674: 'reach',
#  675: 'promises',
#  676: 'tweet',
#  677: 'baghdad',
#  678: 'finance',
#  679: 'euro',
#  680: 'leading',
#  681: 'denies',
#  682: 'insurance',
#  683: 'biden',
#  684: 'zealand',
#  685: 'within',
#  686: 'transition',
#  687: 'fighting',
#  688: 'mate',
#  689: 'beijing',
#  690: 'finds',
#  691: 'sec',
#  692: '7',
#  693: '30',
#  694: 'criticizes',
#  695: 'holds',
#  696: 'evidence',
#  697: 'kushner',
#  698: 'issue',
#  699: 'social',
#  700: 'agree',
#  701: 'economic',
#  702: "canada's",
#  703: 'indian',
#  704: 'accept',
#  705: 'fair',
#  706: 'boost',
#  707: 'commerce',
#  708: 'country',
#  709: 'save',
#  710: 'give',
#  711: 'conservative',
#  712: 'discussed',
#  713: 'sentences',
#  714: 'pension',
#  715: 'nato',
#  716: 'black',
#  717: 'condemns',
#  718: 'style',
#  719: '4',
#  720: 'town',
#  721: 'again',
#  722: 'cabinet',
#  723: 'allow',
#  724: 'expected',
#  725: 'step',
#  726: 'vp',
#  727: 'indonesia',
#  728: 'bangladesh',
#  729: 'investigating',
#  730: 'bail',
#  731: 'prince',
#  732: 'now',
#  733: 'unity',
#  734: '2016',
#  735: 'central',
#  736: 'submarine',
#  737: 'european',
#  738: 'militant',
#  739: "'very",
#  740: 'ohio',
#  741: 'jr',
#  742: 'carolina',
#  743: 'strategy',
#  744: 'brussels',
#  745: 'position',
#  746: 'spending',
#  747: 'launch',
#  748: 'moves',
#  749: 'toward',
#  750: 'sept',
#  751: 'thai',
#  752: 'remains',
#  753: 'xinhua',
#  754: 'injured',
#  755: 'w',
#  756: 'fiscal',
#  757: 'mulls',
#  758: 'pressure',
#  759: "yemen's",
#  760: 'toll',
#  761: 'blocks',
#  762: 'ads',
#  763: 'chairman',
#  764: 'drills',
#  765: 'mattis',
#  766: 'focus',
#  767: 'halt',
#  768: 'protest',
#  769: 'staff',
#  770: 'financial',
#  771: 'cooperation',
#  772: 'their',
#  773: 'mosque',
#  774: 'suggests',
#  775: 'middle',
#  776: 'homeland',
#  777: 'high',
#  778: 'economy',
#  779: 'weeks',
#  780: 'delays',
#  781: 'come',
#  782: 'through',
#  783: 'abuse',
#  784: 'bar',
#  785: 'sex',
#  786: 'program',
#  787: 'congressman',
#  788: 'line',
#  789: 'missing',
#  790: 'looms',
#  791: 'thousands',
#  792: 'raid',
#  793: 'havana',
#  794: 'shift',
#  795: 'pushes',
#  796: 'concern',
#  797: 'tower',
#  798: 'demands',
#  799: 'others',
#  800: 'alone',
#  801: 'questions',
#  802: 'proposes',
#  803: 'voting',
#  804: 'home',
#  805: 'further',
#  806: 'demand',
#  807: 'leaving',
#  808: 'targeted',
#  809: 'charged',
#  810: 'rubio',
#  811: 'crackdown',
#  812: 'study',
#  813: 'monday',
#  814: 'service',
#  815: 'what',
#  816: 'flights',
#  817: 'made',
#  818: 'immigrant',
#  819: 'emergency',
#  820: 'were',
#  821: 'deportation',
#  822: 'g20',
#  823: 'countries',
#  824: 'spokeswoman',
#  825: 'told',
#  826: 'potential',
#  827: "president's",
#  828: 'quit',
#  829: 'gmt',
#  830: 'record',
#  831: 'shut',
#  832: 'troops',
#  833: 'address',
#  834: 'fears',
#  835: 'slams',
#  836: 'deputy',
#  837: 'complains',
#  838: 'interference',
#  839: 'down',
#  840: 'interior',
#  841: 'assad',
#  842: 'libyan',
#  843: 'coast',
#  844: 'italy',
#  845: 'access',
#  846: 'services',
#  847: 'records',
#  848: 'stand',
#  849: 'juncker',
#  850: 'unveils',
#  851: 'seekers',
#  852: 'murder',
#  853: 'ny',
#  854: 'canadian',
#  855: 'names',
#  856: 'impact',
#  857: 'heads',
#  858: '2015',
#  859: 'while',
#  860: 'mexicans',
#  861: 'philippines',
#  862: 'words',
#  863: 'tension',
#  864: 'peninsula',
#  865: 'lawyers',
#  866: 'measure',
#  867: 'hope',
#  868: 'southeast',
#  869: 'counsel',
#  870: 'probes',
#  871: 'cites',
#  872: 'become',
#  873: 'hurting',
#  874: 'danish',
#  875: 'hurt',
#  876: 'target',
#  877: 'ballot',
#  878: 'islamist',
#  879: 'tensions',
#  880: 'independent',
#  881: "'not",
#  882: 'italian',
#  883: 'try',
#  884: 'opioid',
#  885: 'they',
#  886: 'brazil',
#  887: 'dialogue',
#  888: 'life',
#  889: 'agrees',
#  890: 'guilty',
#  891: 'tough',
#  892: 'launches',
#  893: 'counter',
#  894: 'commander',
#  895: 'crimes',
#  896: 'nomination',
#  897: 'plane',
#  898: 'treatment',
#  899: 'email',
#  900: 'jersey',
#  901: "peru's",
#  902: 'legislation',
#  903: 'only',
#  904: 'final',
#  905: 'colombia',
#  906: 'crime',
#  907: 'testimony',
#  908: "senate's",
#  909: 'interest',
#  910: 'hong',
#  911: 'kong',
#  912: 'disclose',
#  913: 'part',
#  914: 'international',
#  915: 'lift',
#  916: 'regulator',
#  917: 'grants',
#  918: 'ends',
#  919: 'way',
#  920: 'alliance',
#  921: 'defeat',
#  922: 'radio',
#  923: 'london',
#  924: 'resolution',
#  925: 'asia',
#  926: 'moore',
#  927: 'democracy',
#  928: 'loan',
#  929: '3',
#  930: 'clash',
#  931: 'criminal',
#  932: 'premier',
#  933: 'emails',
#  934: 'conservatives',
#  935: 'sues',
#  936: 'thaad',
#  937: 'tv',
#  938: 'provide',
#  939: 'inquiry',
#  940: 'primary',
#  941: 'resolve',
#  942: 'truck',
#  943: 'swiss',
#  944: 'suspect',
#  945: 'union',
#  946: 'links',
#  947: 'fix',
#  948: 'work',
#  949: "syria's",
#  950: 'might',
#  951: 'news',
#  952: 'measures',
#  953: 'navy',
#  954: "'a",
#  955: 'just',
#  956: 'shows',
#  957: 'bomber',
#  958: 'due',
#  959: 'begins',
#  960: 'zuma',
#  961: 'weapons',
#  962: 'pastor',
#  963: 'era',
#  964: 'buy',
#  965: 'lavrov',
#  966: 'found',
#  967: 'shutdown',
#  968: 'class',
#  969: 'australian',
#  970: 'contract',
#  971: 'drill',
#  972: 'hotel',
#  973: 'us',
#  974: 'name',
#  975: 'rises',
#  976: 'feud',
#  977: 'minority',
#  978: 'raqqa',
#  979: '50',
#  980: 'during',
#  981: "progress'",
#  982: 'away',
#  983: 'center',
#  984: 'american',
#  985: 'university',
#  986: 'appears',
#  987: 'killing',
#  988: 'philippine',
#  989: 'marriage',
#  990: 'victory',
#  991: 'terms',
#  992: 'around',
#  993: 'venezuelan',
#  994: 'seeking',
#  995: 'leaves',
#  996: 'aides',
#  997: 'moving',
#  998: 'worst',
#  999: 'sent',
#  1000: 'tpp',
#  ...}

# %%
# Cantidad de palabras en el vocabulario
vocab_size = len(tok.word_counts)
vocab_size
# Out:
# 4813

# %%
# El índice para cada palabra
# El sistema las ordena de las más populares a las menos populares
print(tok.word_index)
# Out:
# {'to': 1, 'trump': 2, 'u': 3, 'in': 4, 's': 5, 'on': 6, 'says': 7, 'of': 8, 'for': 9, 'with': 10, 'house': 11, 'as': 12, 'over': 13, 'after': 14, 'north': 15, 'not': 16, 'new': 17, 'russia': 18, 'korea': 19, 'at': 20, 'from': 21, 'state': 22, 'white': 23, "trump's": 24, 'senate': 25, 'will': 26, 'obama': 27, 'court': 28, 'by': 29, 'vote': 30, 'and': 31, 'china': 32, 'n': 33, 'tax': 34, 'republican': 35, 'bill': 36, 'eu': 37, 'deal': 38, 'be': 39, 'iran': 40, 'president': 41, 'a': 42, 'clinton': 43, 'factbox': 44, 'south': 45, 'brexit': 46, 'chief': 47, 'sanctions': 48, 'minister': 49, 'the': 50, 'may': 51, 'election': 52, 'republicans': 53, 'russian': 54, 'talks': 55, 'pm': 56, 'against': 57, 'ex': 58, 'turkey': 59, 'saudi': 60, 'meet': 61, 'is': 62, 'no': 63, 'calls': 64, 'government': 65, 'congress': 66, 'military': 67, 'official': 68, 'more': 69, 'putin': 70, 'police': 71, 'security': 72, 'syria': 73, 'nuclear': 74, 'out': 75, 'probe': 76, 'budget': 77, 'defense': 78, 'islamic': 79, 'general': 80, 'attack': 81, 'lawmakers': 82, 'plan': 83, 'trade': 84, 'rights': 85, 'leader': 86, 'german': 87, 'up': 88, 'law': 89, 'into': 90, 'party': 91, 'supreme': 92, 'anti': 93, 'urges': 94, 'healthcare': 95, 'panel': 96, 'governor': 97, 'foreign': 98, 'border': 99, 'travel': 100, 'ban': 101, 'it': 102, 'opposition': 103, 'could': 104, 'top': 105, 'two': 106, 'tells': 107, 'first': 108, 'democrats': 109, 'campaign': 110, 'coalition': 111, 'speaker': 112, 'myanmar': 113, 'discuss': 114, 'about': 115, 'tillerson': 116, 'meeting': 117, 'war': 118, 'million': 119, 'britain': 120, 'mexico': 121, 'iraqi': 122, 'ties': 123, 'jerusalem': 124, 'sources': 125, 'seeks': 126, 'crisis': 127, 'policy': 128, 'ruling': 129, 'presidential': 130, 'senator': 131, 'next': 132, 'week': 133, 'if': 134, 'his': 135, 'missile': 136, 'attorney': 137, 'amid': 138, 'nominee': 139, 'kurdish': 140, 'air': 141, 'has': 142, 'move': 143, 'should': 144, 'killed': 145, 'forces': 146, 'but': 147, 'ready': 148, 'off': 149, 'exclusive': 150, 'wants': 151, 'warns': 152, 'one': 153, 'would': 154, 'former': 155, 'reform': 156, 'senators': 157, 'visit': 158, 'israel': 159, 'support': 160, 'uk': 161, 'twitter': 162, 'aid': 163, 'case': 164, 'take': 165, 'end': 166, 'he': 167, 'officials': 168, 'fbi': 169, 'merkel': 170, 'leaders': 171, 'administration': 172, 'right': 173, 'ryan': 174, 'rohingya': 175, 'iraq': 176, 'army': 177, 'force': 178, 'test': 179, 'kremlin': 180, 'media': 181, 'catalan': 182, 'must': 183, 'secretary': 184, 'judge': 185, 'seek': 186, 'threat': 187, 'kill': 188, 'possible': 189, 'make': 190, 'department': 191, 'back': 192, 'approves': 193, 'call': 194, 'before': 195, 'four': 196, 'bid': 197, 'trial': 198, 'open': 199, 'obamacare': 200, 'catalonia': 201, 'ahead': 202, 'sees': 203, 'kills': 204, 'race': 205, 'comments': 206, 'comey': 207, 'korean': 208, 'syrian': 209, 'help': 210, 'pick': 211, 'immigration': 212, 'rally': 213, 'decision': 214, 'health': 215, 'macron': 216, 'states': 217, 'parliament': 218, 'run': 219, 'aide': 220, 'flynn': 221, 'puerto': 222, 'rico': 223, 'does': 224, 'statement': 225, 'three': 226, 'fight': 227, 'action': 228, 'key': 229, 'set': 230, 'political': 231, 'who': 232, 'summit': 233, 'york': 234, 'presidency': 235, 'lead': 236, 'reuters': 237, 'agencies': 238, 'dead': 239, 'asks': 240, 'rules': 241, 'washington': 242, 'turkish': 243, 'than': 244, 'democratic': 245, 'backs': 246, 'reports': 247, '1': 248, 'source': 249, 'climate': 250, "china's": 251, 'xi': 252, 'japan': 253, 'group': 254, 'committee': 255, 'capital': 256, 'rule': 257, 'jobs': 258, 'debate': 259, 'oil': 260, 'arrested': 261, 'say': 262, 'far': 263, 'legal': 264, 'expects': 265, 'issues': 266, 'france': 267, 'poll': 268, 'control': 269, 'protests': 270, 'march': 271, 'germany': 272, 'independence': 273, 'that': 274, 'chair': 275, 'this': 276, 'adviser': 277, 'people': 278, 'post': 279, 'arabia': 280, 'erdogan': 281, 'latest': 282, 'agency': 283, 'sessions': 284, 'zimb ...

# %%
# Cantidad de veces quea aparece cada palabra en cada "documento"
# (1 documento = 1 caso de entrada)
print(tok.word_docs)
# Out:
# defaultdict(<class 'int'>, {"turkey's": 5, 'too': 3, 'far': 11, 'emergency': 4, 'says': 290, 'rights': 27, 'go': 10, 'watchdog': 7, 'europe': 3, 'laws': 1, 'deportation': 4, 'from': 72, 'targets': 6, 'given': 2, 'exclusive': 18, 'illegal': 3, 'trump': 477, 'were': 4, 'reprieves': 1, 'who': 12, 'by': 61, 'immigrants': 3, 'obama': 65, 'at': 77, 'in': 435, '639': 1, 'million': 21, 'to': 679, 'aid': 17, 'countries': 4, 'summit': 12, 'four': 14, 'g20': 4, 'pledges': 1, "'bridgegate'": 3, 'trial': 14, 'bid': 14, 'lose': 3, 'associates': 2, 'christie': 5, 'for': 256, 'case': 17, 'new': 81, 'ex': 37, "sanders'": 1, 'more': 32, 'blacks': 1, 'white': 68, 'house': 140, 'bernie': 3, 'open': 14, 'young': 2, 'york': 12, 'general': 29, 'obamacare': 14, 'will': 66, 'attorney': 19, 'repeal': 2, 'over': 93, 'sue': 3, 'indonesian': 8, 'graft': 10, 'investigation': 5, 'speaker': 22, 'quits': 2, 'amid': 19, 'parliament': 13, 'lender': 1, 'spanish': 9, 'transfer': 1, 'sabadell': 1, 'legal': 11, 'spokeswoman': 4, 'base': 2, 'alicante': 1, 'lacks': 3, 'cnn': 9, 'tells': 23, 'votes': 9, 'healthcare': 26, 'bill': 52, 'can': 8, 'citizens': 3, 'britain': 21, 'brexit': 42, 'expects': 11, 'most': 10, 'stay': 10, 'after': 92, 'eu': 51, 'aircraft': 3, 'told': 4, 'lockheed': 3, 'pressures': 1, 'price': 2, 'out': 30, 'fighter': 2, 'boeing': 5, 'president': 48, 'nieto': 3, 'meet': 36, 'wednesday': 8, 'mexico': 21, 'pena': 3, 'on': 301, 'queried': 1, 'handling': 2, 'of': 272, 'a': 48, 'security': 31, 'information': 3, 'panel': 26, 'mar': 3, 'lago': 3, "doesn't": 1, 'deal': 51, 'without': 8, 'minister': 41, 'think': 3, 'leave': 7, 'transport': 1, 'factbox': 47, 'list': 7, 'short': 2, 'picks': 9, 'administration': 16, 'potential': 4, 'appealed': 1, 'escalation': 2, 'rajoy': 2, 'tusk': 5, 'avoid': 10, 'catalonia': 13, "eu's": 8, 'assaults': 1, 'steep': 1, 'rise': 2, 'limit': 5, 'sales': 3, 'acid': 1, 'issues': 11, 'challenge': 7, 'first': 23, "trump's": 68, 'travel': 24, 'hawaii': 5, 'ban': 24, 'ally': 3, 'poses': 1, 'probe': 30, "president's": 4, 'into': 27, 'elections': 9, 'tricky': 2, 'ahead': 14, 'right': 16, 'quit': 4, 'major': 9, 'blow': 7, 'co': 5, 'afd': 3, 'leader': 28, "germany's": 9, 'munich': 1, 'german': 28, 'shooter': 1, 'gun': 9, 'selling': 1, 'attack': 29, 'admits': 2, 'and': 60, 'north': 87, 'schools': 5, 'role': 10, 'hospitals': 3, 'syria': 30, 'turkey': 36, 'carves': 1, 'bln': 1, 'gap': 3, "'time": 1, "bomb'": 1, 'budget': 29, 'pennsylvania': 3, '2': 7, 'is': 36, 'governor': 26, 'the': 39, '6': 10, '21': 3, 'gmt': 4, 'april': 7, 'presidency': 12, 'm': 9, 'edt': 6, 'highlights': 10, 'p': 9, '12': 3, '2212': 1, 'flint': 8, 'charges': 5, 'crisis': 20, 'michigan': 8, 'no': 36, 'newspaper': 3, 'hollande': 1, 'push': 10, 's': 404, 'as': 105, 'sees': 14, 'u': 441, 'france': 11, 'peace': 9, 'talks': 38, 'strike': 9, 'tool': 2, '13': 6, 'expands': 3, 'ipsos': 8, 'clinton': 48, 'poll': 11, 'points': 5, 'reuters': 12, 'lead': 12, 'working': 8, 'opposes': 3, 'with': 156, 'democrats': 23, 'ryan': 16, 'south': 46, 'vote': 61, 'steps': 5, "africa's": 7, 'anc': 3, 'leadership': 5, 'ramaphosa': 2, 'criticism': 5, 'up': 28, 'doctors': 1, 'border': 25, 'drama': 2, 'koreans': 2, 'funding': 8, 'care': 6, 'defector': 1, 'trauma': 1, 'urge': 10, 'drives': 1, 'kills': 14, 'moscow': 8, 'bus': 2, 'underpass': 1, 'pedestrian': 1, 'agencies': 12, 'putin': 32, 'eye': 5, 'policy': 20, 'see': 10, 'foreign': 25, 'aims': 6, 'many': 6, 'fox': 2, 'goldman': 1, 'partner': 2, 'wants': 18, 'mnuchin': 6, 'run': 13, 'treasury': 6, 'business': 9, 'national': 8, 'terrorism': 6, 'defends': 5, 'speech': 5, 'record': 4, 'republicans': 39, 'poised': 2, 'california': 7, 'shut': 4, 'senate': 66, 'race': 14, 'stung': 1, 'reputation': 1, 'laundering': 2, 'money': 6, 'corner': 1, 'looks': 3, 'taiwan': 8, 'turn': 5, 'myanmar': 22, 'qaeda': 3, 'al': 8, 'warns': 18, 'rohingya': 16, "'punishment'": 1, 'light': 2, 'dead': 12, 'collides': 2, 'one': 18, 'caernarfon': 1, 'runway': 1, 'military': 33, 'gov ...

# %% [markdown]
# ### Definir el modelo

# %%
model = Sequential()

# la primera capa es de embedding entrenable. Recordar que se puede variar el tamaño
# del embedding a entrenar
model.add(Embedding(input_dim=vocab_size+1, output_dim=50, input_shape=(None,)))

model.add(LSTM(100, return_sequences=True))
# model.add(Dropout(0.2))

model.add(LSTM(100, return_sequences=True))
# model.add(Dense(32, activation='relu'))

# Predicción de clasificación con softmax
# La salida es del tamaño del vocabulario
model.add(Dense(vocab_size+1, activation='softmax'))


# Clasificación multiple categórica --> loss = categorical_crossentropy
# notar que usamos la versión Sparse para utilizar sólo índices en lugar de OHE
model.compile(loss=SparseCategoricalCrossentropy(), optimizer='rmsprop')

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, None, 50)            │         240,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, None, 100)           │          60,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, None, 100)           │          80,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, None, 4814)          │         486,214 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 867,714 (3.31 MB)
#  Trainable params: 867,714 (3.31 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Dado que por el momento no hay implementaciones adecuadas de la perplejidad que puedan operar en tiempo de entrenamiento, armaremos un Callback *ad-hoc* que la calcule en cada epoch.
#
# **Nota**: un Callback es una rutina gatillada por algún evento, son muy útiles para relevar datos en diferentes momentos del desarrollo del modelo. En este caso queremos hacer un cálculo cada vez que termina una epoch de entrenamiento.

# %%
class PplCallback(keras.callbacks.Callback):
    '''
    Este callback es una solución ad-hoc para calcular al final de cada epoch de
    entrenamiento la métrica de Perplejidad sobre un conjunto de datos de validación.
    La perplejidad es una métrica cuantitativa para evaluar la calidad de la generación de secuencias.
    Además implementa la finalización del entrenamiento (Early Stopping)
    si la perplejidad no mejora después de `patience` epochs.
    '''

    def __init__(self, val_data, history_ppl, patience=5):
        # El callback lo inicializamos con secuencias de validación sobre las cuales
        # mediremos la perplejidad y la paciencia para detener el entrenamiento.
        self.val_data = val_data
        self.history_ppl = history_ppl
        self.patience = patience

        self.target = []
        self.padded = []

        count = 0
        self.info = []
        self.min_score = np.inf
        self.patience_counter = 0

        # nos movemos en todas las secuencias de los datos de validación
        for seq in self.val_data:
            len_seq = len(seq)
            # armamos todas las subsecuencias
            subseq = [seq[:i] for i in range(len_seq)]
            self.target.extend([seq[i] for i in range(len_seq)])

            if len(subseq) != 0:
                self.padded.append(pad_sequences(subseq, maxlen=max_context_size+1, padding='pre'))
                self.info.append((count, count+len_seq))
                count += len_seq

        self.padded = np.vstack(self.padded)

    def on_epoch_end(self, epoch, logs=None):
        # en `scores` iremos guardando la perplejidad de cada secuencia
        scores = []

        # Calculamos las predicciones sobre el conjunto de validación
        predictions = self.model.predict(self.padded, verbose=0)

        # para cada secuencia de validación
        for start, end in self.info:
            # en `probs` iremos guardando las probabilidades de los términos target
            probs = [predictions[idx_seq, -1, idx_vocab] for idx_seq, idx_vocab in zip(range(start, end), self.target[start:end])]

            # calculamos la perplejidad por medio de logaritmos
            scores.append(np.exp(-np.sum(np.log(probs)) / (end - start)))

        # promediamos todos los scores e imprimimos el valor promedio
        current_score = np.mean(scores)
        self.history_ppl.append(current_score)
        print(f'\nMean perplexity: {current_score:.4f}\n')

        # chequeamos si tenemos que detener el entrenamiento
        if current_score < self.min_score:
            self.min_score = current_score
            model_filename = f"my_model_{epoch+1}_{current_score:.4f}.h5"
            self.model.save(model_filename)
            print(f"Saved new model as {model_filename}!")
            self.patience_counter = 0
        else:
            self.patience_counter += 1
            if self.patience_counter == self.patience:
                print("Stopping training...")
                self.model.stop_training = True

# %% [markdown]
# ### Entrenamiento

# %%
# fiteamos, nótese el agregado del callback con su inicialización. El batch_size lo podemos seleccionar a mano
# en general, lo mejor es escoger el batch más grande posible que minimice el tiempo de cada época.
# En la variable `history_ppl` se guardarán los valores de perplejidad para cada época.
history_ppl = []
hist = model.fit(X, y, epochs=10, callbacks=[PplCallback(tokenized_sentences_val, history_ppl)], batch_size=64)
# Out:
# Epoch 1/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 5.8600
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Mean perplexity: 2061.3151
#
# Saved new model as my_model_1_2061.3151.h5!
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 114s 264ms/step - loss: 5.8581
# Epoch 2/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 4.5926
# Mean perplexity: 2082.9146
#
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 104s 249ms/step - loss: 4.5926
# Epoch 3/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 4.5025
# Mean perplexity: 2140.3048
#
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 92s 219ms/step - loss: 4.5025
# Epoch 4/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 4.4376
# Mean perplexity: 2127.2857
#
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 154s 250ms/step - loss: 4.4376
# Epoch 5/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 4.3672
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Mean perplexity: 2012.1612
#
# Saved new model as my_model_5_2012.1612.h5!
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 107s 256ms/step - loss: 4.3672
# Epoch 6/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 4.2778
# Mean perplexity: 2652.2319
#
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 139s 248ms/step - loss: 4.2778
# Epoch 7/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 4.2377
# Mean perplexity: 2796.3049
#
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - loss: 4.2376
# Epoch 8/10
# 418/419 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.1617
# Mean perplexity: 2774.1379
#
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 93s 221ms/step - loss: 4.1616
# Epoch 9/10
# 418/419 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - loss: 4.0715
# Mean perplexity: 3114.1691
#
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 139s 216ms/step - loss: 4.0715
# Epoch 10/10
# 418/419 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 4.0286
# Mean perplexity: 3217.4428
#
# Stopping training...
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 153s 242ms/step - loss: 4.0286

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Podemos graficar la evolución de la perplejidad con las épocas.
# Recordar que el valor de perplejidad del modelo trivial es el tamaño del vocabulario.
epoch_count = range(1, len(history_ppl) + 1)

plt.figure(figsize=(10, 6))
sns.lineplot(x=epoch_count, y=history_ppl, marker='o')
plt.title('Evolución de la Perplejidad durante el Entrenamiento')
plt.xlabel('Época')
plt.ylabel('Perplejidad')
plt.grid(True)
plt.show()

# %%
import glob

model_files = glob.glob('my_model_*.h5')
if model_files:
    # Ordena los archivos por el valor de perplejidad en el nombre
    model_files.sort(key=lambda x: float(x.split('_')[-1].replace('.h5', '')))
    best_model_file = model_files[-1]  # El archivo con la menor perplejidad
    print(f'Cargando el mejor modelo: {best_model_file}')
    model = keras.models.load_model(best_model_file)
else:
    print("No se encontraron archivos de modelo.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Cargando el mejor modelo: my_model_1_2061.3151.h5

# %%
# # Cargamos el mejor modelo guardado del entrenamiento para hacer inferencia
# model = keras.models.load_model('my_model')

# %% [markdown]
# ### Predicción de próxima palabra

# %%
# Se puede usar gradio para probar el modelo
# Gradio es una herramienta muy útil para crear interfaces para ensayar modelos
# https://gradio.app/

# !pip install -q gradio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 84.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.6/318.6 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 69.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 61.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.5 MB/s eta 0:00:00

# %%
import gradio as gr

def model_response(human_text):

    # Encodeamos
    encoded = tok.texts_to_sequences([human_text])[0]
    # Si tienen distinto largo
    encoded = pad_sequences([encoded], maxlen=max_context_size, padding='pre')

    # Predicción softmax
    y_hat = np.argmax(model.predict(encoded)[0,-1,:])


    # Debemos buscar en el vocabulario la palabra
    # que corresopnde al indice (y_hat) predicho por le modelo
    out_word = ''
    for word, index in tok.word_index.items():
        if index == y_hat:
            out_word = word
            break

    # Agrego la palabra a la frase predicha
    return human_text + ' ' + out_word

iface = gr.Interface(
    fn=model_response,
    inputs=["textbox"],
    outputs="text")

iface.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://c5f3a65c3cc6afa5ca.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c5f3a65c3cc6afa5ca.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://c5f3a65c3cc6afa5ca.gradio.live

# %% [markdown]
# ### Generación de secuencias

# %%
def generate_seq(model, tokenizer, seed_text, max_length, n_words):
    """
        Exec model sequence prediction

        Args:
            model (keras): modelo entrenado
            tokenizer (keras tokenizer): tonenizer utilizado en el preprocesamiento
            seed_text (string): texto de entrada (input_seq)
            max_length (int): máxima longitud de la sequencia de entrada
            n_words (int): números de palabras a agregar a la sequencia de entrada
        returns:
            output_text (string): sentencia con las "n_words" agregadas
    """
    output_text = seed_text
	  # generate a fixed number of words
    for _ in range(n_words):
		  # Tokenizamos
      encoded = tokenizer.texts_to_sequences([output_text])[0]

		  # Si tienen distinto largo
      encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')

		  # Predicción softmax
      y_hat = np.argmax(model.predict(encoded)[0,-1,:])

      # Vamos concatenando las predicciones
      out_word = ''

      # Debemos buscar en el vocabulario la palabra
      # que corresopnde al indice (y_hat) predicho por le modelo
      for word, index in tokenizer.word_index.items():
        if index == y_hat:
          out_word = word
          break

		  # Agrego las palabras a la frase predicha
      output_text += ' ' + out_word

    return output_text

# %%
input_text='donald trump\'t'

generate_seq(model, tok, input_text, max_length=max_context_size, n_words=10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# "donald trump't to to to to to to to to to to"

# %% [markdown]
# ###  Beam search y muestreo aleatorio

# %%
# funcionalidades para hacer encoding y decoding

def encode(text,max_length=max_context_size):

    encoded = tok.texts_to_sequences([text])[0]
    encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')

    return encoded

def decode(seq):
    return tok.sequences_to_texts([seq])

# %%
from scipy.special import softmax

# función que selecciona candidatos para el beam search
def select_candidates(pred,num_beams,vocab_size,history_probs,history_tokens,temp,mode):

  # colectar todas las probabilidades para la siguiente búsqueda
  pred_large = []

  for idx,pp in enumerate(pred):
    pred_large.extend(np.log(pp+1E-10)+history_probs[idx])

  pred_large = np.array(pred_large)

  # criterio de selección
  if mode == 'det':
    idx_select = np.argsort(pred_large)[::-1][:num_beams] # beam search determinista
  elif mode == 'sto':
    idx_select = np.random.choice(np.arange(pred_large.shape[0]), num_beams, p=softmax(pred_large/temp)) # beam search con muestreo aleatorio
  else:
    raise ValueError(f'Wrong selection mode. {mode} was given. det and sto are supported.')

  # traducir a índices de token en el vocabulario
  new_history_tokens = np.concatenate((np.array(history_tokens)[idx_select//vocab_size],
                        np.array([idx_select%vocab_size]).T),
                      axis=1)

  # devolver el producto de las probabilidades (log) y la secuencia de tokens seleccionados
  return pred_large[idx_select.astype(int)], new_history_tokens.astype(int)


def beam_search(model,num_beams,num_words,input,temp=1,mode='det'):

    # first iteration

    # encode
    encoded = encode(input)

    # first prediction
    y_hat = model.predict(encoded,verbose=0)[0,-1,:]

    # get vocabulary size
    vocab_size = y_hat.shape[0]

    # initialize history
    history_probs = [0]*num_beams
    history_tokens = [encoded[0]]*num_beams

    # select num_beams candidates
    history_probs, history_tokens = select_candidates([y_hat],
                                        num_beams,
                                        vocab_size,
                                        history_probs,
                                        history_tokens,
                                        temp,
                                        mode)

    # beam search loop
    for i in range(num_words-1):

      preds = []

      for hist in history_tokens:

        # actualizar secuencia de tokens
        input_update = np.array([hist[i+1:]]).copy()

        # predicción
        y_hat = model.predict(input_update,verbose=0)[0,-1,:]

        preds.append(y_hat)

      history_probs, history_tokens = select_candidates(preds,
                                                        num_beams,
                                                        vocab_size,
                                                        history_probs,
                                                        history_tokens,
                                                        temp,
                                                        mode)

    return history_tokens

# %%
# predicción con beam search.
# Se pueden camiar los modos entre 'det' (determinista) y
# 'sto' (estocástico)
# para el caso estocástico también se puede variar la temperatura
salidas = beam_search(model,num_beams=10,num_words=6,input="donald trump says about russia",temp=1,mode='sto')

# %%
# tenemos `num_beams` salidas ordenadas de mayor a menor likelihood
salidas.shape
# Out:
# (10, 15)

# %%
# veamos las salidas
decode(salidas[0])
# Out:
# ['donald trump says about russia to says should to of prince']
