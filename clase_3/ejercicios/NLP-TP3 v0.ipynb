# %% [markdown]
# <img src="https://github.com/hernancontigiani/ceia_memorias_especializacion/raw/master/Figures/logoFIUBA.jpg" width="500" align="center">
#
#
# # Procesamiento de lenguaje natural
# ## Modelo de lenguaje con tokenización por palabras

# %% [markdown]
# ### Consigna
# - Seleccionar un corpus de texto sobre el cual entrenar el modelo de lenguaje.
# - Realizar el pre-procesamiento adecuado para tokenizar el corpus, estructurar el dataset y separar entre datos de entrenamiento y validación.
# - Proponer arquitecturas de redes neuronales basadas en unidades recurrentes para implementar un modelo de lenguaje.
# - Con el o los modelos que consideren adecuados, generar nuevas secuencias a partir de secuencias de contexto con las estrategias de greedy search y beam search determístico y estocástico. En este último caso observar el efecto de la temperatura en la generación de secuencias.
#
#
# ### Sugerencias
# - Durante el entrenamiento, guiarse por el descenso de la perplejidad en los datos de validación para finalizar el entrenamiento. Para ello se provee un callback.
# - Explorar utilizar SimpleRNN (celda de Elman), LSTM y GRU.
# - rmsprop es el optimizador recomendado para la buena convergencia. No obstante se pueden explorar otros.

# %%
import random
import io
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras import layers
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %% [markdown]
# ### Datos
# Como ejemplo se utilizará como corpus un dataset canciones de bandas de habla inglés.

# %%
# Leer el archivo CSV
url = 'https://raw.githubusercontent.com/sevann-radhak/procesamiento_lenguaje_natural/main/clase_2/ejercicios/raw/True.csv'
df = pd.read_csv(url)

# %% [markdown]
# Consideraremos que cada secuencia para este dataset es un verso.
#
# Una de las primeras decisiones que hay que tomar es el tamaño de contexto de tokens máximo que puede consumir el modelo. Este podría ser un hiperparámetro del problema.
#
# Para elegir el tamaño de contexto máximo para este problema se puede explorar el dataset, para ello:
# - se consideran las palabras como términos.
# - se segmentará el texto de todos los versos del dataset y ses explorará la cantidad de términos presentes.

# %%
print("Cantidad de documentos:", df.shape[0])
# Out:
# Cantidad de documentos: 21417

# %%
df = df[['title']].sample(n=3000)
# df = df[['title']].sample(n=2000, random_state=42)

print("Cantidad de documentos:", df.shape[0])
# Out:
# Cantidad de documentos: 3000

# %% [markdown]
# ### Elegir el tamaño del contexto

# %%
# Usaremos las utilidades de procesamiento de textos y secuencias de Keras
from tensorflow.keras.preprocessing.text import Tokenizer # equivalente a ltokenizer de nltk
from tensorflow.keras.preprocessing.text import text_to_word_sequence # equivalente a word_tokenize de nltk
from tensorflow.keras.utils import pad_sequences # se utilizará para padding

# %%
# cada title lo guardamos en una lista
text = df['title'].tolist()

# %%
# Ver algunos ejemplos
print(text[:2])
# Out:
# ['Rohingyas must go home but to safety, Bangladesh says', 'House Republicans float controversial budget plan']

# %%
# segmentamos el texto con la utilidad de Keras
segmented_sentences = [text_to_word_sequence(sentence) for sentence in text]

# %%
text[0]
# Out:
# 'Rohingyas must go home but to safety, Bangladesh says'

# %%
segmented_sentences[0]
# Out:
# ['rohingyas',
#  'must',
#  'go',
#  'home',
#  'but',
#  'to',
#  'safety',
#  'bangladesh',
#  'says']

# %%
# calculamos la longitud de cada secuencia
length_sentences = [len(sentence) for sentence in segmented_sentences]

# %%
# podemos ver su distribución
plt.hist(length_sentences, bins=10)
# Out:
# (array([2.800e+01, 4.150e+02, 5.490e+02, 1.269e+03, 4.090e+02, 2.860e+02,
#         3.800e+01, 5.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 5. ,  6.6,  8.2,  9.8, 11.4, 13. , 14.6, 16.2, 17.8, 19.4, 21. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Nota:** Dado el histograma de la distribución de longitudes de secuencias, parece que una gran parte de las secuencias tiene una longitud entre 5 y 12 palabras, con muy pocas secuencias más largas. Para asegurar que nuestro modelo sea eficiente y capture la mayoría de las secuencias sin incluir demasiado padding, podemos usar la mediana como criterio para definir el tamaño máximo del contexto.

# %%
# a partir de la distribución de longitudes de secuencias elegimos algún criterio
# para determinar el máximo tamaño de contexto. En este caso es un percentil, pero
# otros criterios también pueden ser válidos con la justificación adecuada.
# También puede ser una selección "a mano"

# el -1 es porque el último token será el target
max_context_size = int(np.ceil(np.median(length_sentences)) - 1)

print(f'max_context_size: {max_context_size}')
# Out:
# max_context_size: 9

# %% [markdown]
# ###  Tokenizar

# %%
# instanciamos el tokenizador
tok = Tokenizer()

# El tokenizer "aprende" las palabras que se usaran
# Se construye (fit) una vez por proyecto, se aplica N veces (tal cual un encoder)
# El token 0 es reservado y no es asignado. Se utiliza para designar a palabras
# fuera del vocabulario aprendido
tok.fit_on_texts(segmented_sentences)

# Convertimos las palabras a números
# entran palabras -> salen números
tokenized_sentences = tok.texts_to_sequences(segmented_sentences)

# %%
tokenized_sentences[0]
# Out:
# [1889, 237, 390, 432, 109, 1, 973, 354, 7]

# %%
segmented_sentences[0]
# Out:
# ['rohingyas',
#  'must',
#  'go',
#  'home',
#  'but',
#  'to',
#  'safety',
#  'bangladesh',
#  'says']

# %% [markdown]
# ### Organizando y estructurando el dataset

# %% [markdown]
# En este punto tenemos en la variable `tokenized_sentences` los versos tokenizados. Vamos a quedarnos con un conjunto de validación que utilizaremos para medir la calidad de la generación de secuencias con la métrica de Perplejidad.

# %%
tokenized_sentences_train, tokenized_sentences_val, _, _ = train_test_split(tokenized_sentences, tokenized_sentences, test_size=0.2, random_state=42)

# %% [markdown]
# \Vamos a splitear las oraciones que tienen tamaño mayor al contexto máximo, para generarnos más secuencias de entrenamiento. Este paso puede obviarse si el tamaño de contexto máximo es muy grande.
#
# Por ejemplo, si tenemos el texto *La bella y graciosa moza marchóse a lavar la ropa* y nuestro contexto es de 5 palabras, tendremos:
#
# - *La bella y graciosa moza*
# - *bella y graciosa moza marchóse*
# - *y graciosa moza marchóse a*
# - *graciosa moza marchóse a lavar*
# - *moza marchóse a lavar la*
# - *marchóse a lavar la ropa*

# %%
tok_sent = []

for sent in tokenized_sentences_train:
  # si la secuencia tiene más términos que el tamaño de contexto máximo,
  # armo varias sub-secuencias de tamaño máximo
  if len(sent) > (max_context_size+1):
    extra = len(sent)-(max_context_size+1) + 1
    for i in range(extra):
      tok_sent.append(sent[i:i+max_context_size+1])
  else: # si la secuencia tiene menos términos el tamaño de contexto máximo, dejo la secuencia como está
    tok_sent.append(sent)

# %%
len(tok_sent)
# Out:
# 4534

# %% [markdown]
# Ahora aumentamos los datos aprovechando que de una secuencia grande se pueden generar varias más pequeñas:
#
# - *La hermosa casa en el prado*
# - *La hermosa*
# - *La hermosa casa*
# - *La hermosa casa en*
# - *La hermosa casa en el*
# - *La hermosa casa en el prado*

# %%
tok_sent_augm = []

for sent in tok_sent:

  # generamos todas las sub-secuencias
  subseq = [sent[:i+2] for i in range(len(sent)-1)]
  # en esta línea paddeamos al tamaño de contexto máximo
  tok_sent_augm.append(pad_sequences(subseq, maxlen=max_context_size+1, padding='pre'))

# %%
# finalmente concatenamos todas las secuencias en un único array de numpy
train_seqs = np.concatenate(tok_sent_augm, axis=0)

# %%
train_seqs.shape
# Out:
# (39529, 10)

# %%
# y de aquí sacamos las entradas y los targets que consumirá nuestro sistema en
# tiempo de entrenamiento
X = train_seqs[:,:-1]
y = train_seqs[:,1:]

# %% [markdown]
# Nótese que estamos estructurando el problema de aprendizaje como *many-to-many*:
#
# Entrada: secuencia de tokens [$x_0$, $x_1$, ..., $x_N$]
#
# Target: secuencia de tokens [$x_1$, $x_2$, ..., $x_{N+1}$]
#
# De manera que la red tiene que aprender que su salida deben ser los tokens desplazados en una posición y un nuevo token predicho (el N+1).
#
# La ventaja de estructurar el aprendizaje de esta manera es que para cada token de target se propaga una señal de gradiente por el grafo de cómputo recurrente, que es mejor que estructurar el problema como *many-to-one* en donde sólo una señal de gradiente se propaga.

# %%
y.shape
# Out:
# (39529, 9)

# %%
# Palabras del vocabulario
tok.index_word
# Out:
# {1: 'to',
#  2: 'u',
#  3: 'trump',
#  4: 'in',
#  5: 's',
#  6: 'on',
#  7: 'says',
#  8: 'of',
#  9: 'for',
#  10: 'with',
#  11: 'house',
#  12: 'after',
#  13: 'as',
#  14: 'over',
#  15: 'north',
#  16: 'at',
#  17: 'white',
#  18: 'russia',
#  19: 'new',
#  20: 'korea',
#  21: 'from',
#  22: 'not',
#  23: 'bill',
#  24: 'court',
#  25: 'senate',
#  26: 'obama',
#  27: 'clinton',
#  28: 'republican',
#  29: 'state',
#  30: 'china',
#  31: 'tax',
#  32: 'will',
#  33: 'election',
#  34: "trump's",
#  35: 'deal',
#  36: 'and',
#  37: 'eu',
#  38: 'by',
#  39: 'a',
#  40: 'the',
#  41: 'vote',
#  42: 'may',
#  43: 'be',
#  44: 'south',
#  45: 'talks',
#  46: 'police',
#  47: 'n',
#  48: 'minister',
#  49: 'iran',
#  50: 'chief',
#  51: 'congress',
#  52: 'against',
#  53: 'factbox',
#  54: 'pm',
#  55: 'government',
#  56: 'president',
#  57: 'republicans',
#  58: 'probe',
#  59: 'leader',
#  60: 'brexit',
#  61: 'plan',
#  62: 'law',
#  63: 'calls',
#  64: 'more',
#  65: 'party',
#  66: 'syria',
#  67: 'is',
#  68: 'top',
#  69: 'lawmakers',
#  70: 'up',
#  71: 'ban',
#  72: 'no',
#  73: 'about',
#  74: 'foreign',
#  75: 'healthcare',
#  76: 'saudi',
#  77: 'nuclear',
#  78: 'russian',
#  79: 'myanmar',
#  80: 'military',
#  81: 'trade',
#  82: 'sanctions',
#  83: 'sources',
#  84: 'uk',
#  85: 'presidential',
#  86: 'opposition',
#  87: 'has',
#  88: 'budget',
#  89: 'attack',
#  90: 'it',
#  91: 'could',
#  92: 'security',
#  93: 'urges',
#  94: 'reform',
#  95: 'border',
#  96: 'two',
#  97: 'media',
#  98: 'senator',
#  99: 'aid',
#  100: 'rights',
#  101: 'rohingya',
#  102: 'former',
#  103: 'official',
#  104: 'ex',
#  105: 'putin',
#  106: 'german',
#  107: 'out',
#  108: 'islamic',
#  109: 'but',
#  110: 'turkey',
#  111: 'say',
#  112: 'campaign',
#  113: 'he',
#  114: 'supreme',
#  115: 'panel',
#  116: 'meet',
#  117: 'anti',
#  118: 'obamacare',
#  119: 'korean',
#  120: 'visit',
#  121: 'if',
#  122: 'governor',
#  123: 'catalan',
#  124: 'travel',
#  125: 'coalition',
#  126: 'mexico',
#  127: 'democratic',
#  128: 'would',
#  129: 'under',
#  130: 'tells',
#  131: 'his',
#  132: 'democrats',
#  133: 'killed',
#  134: 'france',
#  135: 'end',
#  136: 'exclusive',
#  137: 'race',
#  138: 'first',
#  139: 'meeting',
#  140: 'discuss',
#  141: 'into',
#  142: 'officials',
#  143: 'ahead',
#  144: 'fight',
#  145: 'seek',
#  146: 'should',
#  147: 'independence',
#  148: 'crisis',
#  149: 'ruling',
#  150: 'that',
#  151: 'parliament',
#  152: 'support',
#  153: 'general',
#  154: 'tillerson',
#  155: 'attacks',
#  156: 'pick',
#  157: 'bid',
#  158: 'wants',
#  159: 'syrian',
#  160: 'lead',
#  161: 'next',
#  162: 'back',
#  163: 'seeks',
#  164: 'debate',
#  165: 'puerto',
#  166: 'poll',
#  167: 'war',
#  168: 'policy',
#  169: 'immigration',
#  170: 'group',
#  171: 'turkish',
#  172: 'speaker',
#  173: 'report',
#  174: 'missile',
#  175: 'britain',
#  176: 'fbi',
#  177: 'help',
#  178: 'post',
#  179: 'ties',
#  180: 'climate',
#  181: 'before',
#  182: 'iraq',
#  183: 'jerusalem',
#  184: 'cut',
#  185: 'leaders',
#  186: 'week',
#  187: 'call',
#  188: 'department',
#  189: 'army',
#  190: 'backs',
#  191: 'ryan',
#  192: 'key',
#  193: 'million',
#  194: 'rico',
#  195: 'off',
#  196: 'its',
#  197: 'judge',
#  198: 'source',
#  199: 'air',
#  200: 'agency',
#  201: 'senators',
#  202: 'states',
#  203: 'have',
#  204: 'adviser',
#  205: 'amid',
#  206: 'reuters',
#  207: 'nominee',
#  208: 'win',
#  209: 'washington',
#  210: 'attorney',
#  211: 'corruption',
#  212: 'xi',
#  213: 'french',
#  214: 'defense',
#  215: 'administration',
#  216: 'threat',
#  217: 'twitter',
#  218: 'order',
#  219: 'sees',
#  220: 'right',
#  221: 'california',
#  222: 'want',
#  223: 'national',
#  224: 'down',
#  225: 'billion',
#  226: 'warns',
#  227: 'secretary',
#  228: 'aide',
#  229: 'kremlin',
#  230: 'business',
#  231: 'hacking',
#  232: 'rules',
#  233: 'three',
#  234: 'israel',
#  235: 'who',
#  236: 'push',
#  237: 'must',
#  238: "china's",
#  239: 'macron',
#  240: 'decision',
#  241: 'takes',
#  242: 'chinese',
#  243: 'make',
#  244: 'one',
#  245: "russia's",
#  246: 'arrested',
#  247: 'pentagon',
#  248: 'hopes',
#  249: 'oil',
#  250: 'catalonia',
#  251: 'intelligence',
#  252: 'kills',
#  253: 'case',
#  254: 'pence',
#  255: '1',
#  256: 'approves',
#  257: 'some',
#  258: 'transgender',
#  259: 'sanders',
#  260: 'health',
#  261: 'political',
#  262: 'japan',
#  263: 'still',
#  264: 'than',
#  265: 'germany',
#  266: 'merkel',
#  267: 'near',
#  268: 'orders',
#  269: 'see',
#  270: 'year',
#  271: 'refugees',
#  272: 'militants',
#  273: 'plans',
#  274: 're',
#  275: 'head',
#  276: 'candidate',
#  277: '2018',
#  278: 'lebanon',
#  279: 'hurricane',
#  280: 'does',
#  281: 'vows',
#  282: 'work',
#  283: 'release',
#  284: 'return',
#  285: 'team',
#  286: 'presidency',
#  287: 'cuba',
#  288: "'",
#  289: 'far',
#  290: 'protest',
#  291: 'justice',
#  292: 'rule',
#  293: 'lawmaker',
#  294: 'email',
#  295: 'review',
#  296: 'venezuela',
#  297: 'democrat',
#  298: 'votes',
#  299: 'protests',
#  300: 'statement',
#  301: 'spain',
#  302: 'graft',
#  303: 'bomb',
#  304: 'carolina',
#  305: 'hariri',
#  306: 'wins',
#  307: 'city',
#  308: 'funding',
#  309: 'ready',
#  310: 'prosecutor',
#  311: 'move',
#  312: 'sign',
#  313: 'refugee',
#  314: 'protesters',
#  315: 'kurdish',
#  316: 'despite',
#  317: 'can',
#  318: 'during',
#  319: 'this',
#  320: 'all',
#  321: 'news',
#  322: 'bank',
#  323: 'denies',
#  324: 'pakistan',
#  325: 'british',
#  326: 'power',
#  327: 'women',
#  328: 'mcconnell',
#  329: "zimbabwe's",
#  330: 'trip',
#  331: 'economic',
#  332: 'an',
#  333: 'how',
#  334: 'faces',
#  335: 'agree',
#  336: 'hold',
#  337: 'strikes',
#  338: 'death',
#  339: 'moves',
#  340: "germany's",
#  341: 'texas',
#  342: 'york',
#  343: "japan's",
#  344: 'al',
#  345: 'tv',
#  346: 'voters',
#  347: 'legal',
#  348: 'arrest',
#  349: 'last',
#  350: 'iraqi',
#  351: 'issues',
#  352: 'northern',
#  353: 'agencies',
#  354: 'bangladesh',
#  355: 'referendum',
#  356: 'launch',
#  357: 'committee',
#  358: 'india',
#  359: 'urge',
#  360: 'stop',
#  361: 'afghan',
#  362: 'program',
#  363: 'six',
#  364: 'rejects',
#  365: 'council',
#  366: 'pass',
#  367: 'test',
#  368: 'philippines',
#  369: 'five',
#  370: 'man',
#  371: 'african',
#  372: 'asks',
#  373: 'run',
#  374: 'cyber',
#  375: 'high',
#  376: 'take',
#  377: 'march',
#  378: 'charges',
#  379: 'or',
#  380: 'dead',
#  381: 'people',
#  382: 'was',
#  383: 'public',
#  384: 'gun',
#  385: 'wall',
#  386: 'zimbabwe',
#  387: 'least',
#  388: 'egypt',
#  389: 'change',
#  390: 'go',
#  391: 'battle',
#  392: 'picks',
#  393: 'islamist',
#  394: 'conservative',
#  395: 'afghanistan',
#  396: 'israeli',
#  397: 'world',
#  398: 'arms',
#  399: 'big',
#  400: 'role',
#  401: 'office',
#  402: 'forces',
#  403: 'speech',
#  404: 'nato',
#  405: 'likely',
#  406: 'kill',
#  407: 'him',
#  408: 'allies',
#  409: 'financial',
#  410: 'transition',
#  411: 'block',
#  412: 'emails',
#  413: 'trial',
#  414: 'nafta',
#  415: '11',
#  416: "eu's",
#  417: 'years',
#  418: 'erdogan',
#  419: 'pope',
#  420: '9',
#  421: 'monday',
#  422: 'talk',
#  423: 'social',
#  424: 'moscow',
#  425: 'finance',
#  426: 'time',
#  427: "won't",
#  428: 'thousands',
#  429: 'irma',
#  430: 'resign',
#  431: 'open',
#  432: 'home',
#  433: "korea's",
#  434: 'experts',
#  435: 'defends',
#  436: 'voting',
#  437: 'spy',
#  438: 'federal',
#  439: 'act',
#  440: 'repeal',
#  441: 'congressional',
#  442: 'what',
#  443: 'soldiers',
#  444: 'held',
#  445: 'close',
#  446: 'florida',
#  447: 'family',
#  448: 'set',
#  449: 'suspect',
#  450: 'hits',
#  451: 'chairman',
#  452: 'clash',
#  453: 'force',
#  454: 'fire',
#  455: 'days',
#  456: 'gets',
#  457: 'are',
#  458: 'appeals',
#  459: 'virginia',
#  460: 'ask',
#  461: 'four',
#  462: 'seen',
#  463: 'envoy',
#  464: 'vietnam',
#  465: 'director',
#  466: 'labor',
#  467: 'split',
#  468: 'senior',
#  469: 'philippine',
#  470: 'paris',
#  471: 'comey',
#  472: 'debt',
#  473: 'migrants',
#  474: 'yemen',
#  475: 'kurds',
#  476: 'pact',
#  477: 'offer',
#  478: 'pension',
#  479: 'gives',
#  480: 'cuts',
#  481: '2',
#  482: 'voter',
#  483: 'percent',
#  484: 'stance',
#  485: 'services',
#  486: 'claims',
#  487: 'dispute',
#  488: 'west',
#  489: "africa's",
#  490: 'deputy',
#  491: 'relief',
#  492: 'pro',
#  493: 'summit',
#  494: 'leave',
#  495: 'join',
#  496: 'vice',
#  497: 'treasury',
#  498: 'mattis',
#  499: 'ends',
#  500: 'day',
#  501: 'effort',
#  502: 'ipsos',
#  503: 'muslim',
#  504: 'way',
#  505: 'center',
#  506: 'p',
#  507: 'm',
#  508: 'signs',
#  509: 'overhaul',
#  510: 'offers',
#  511: 'appeal',
#  512: 'future',
#  513: 'cabinet',
#  514: 'qatar',
#  515: 'face',
#  516: 'migration',
#  517: 'lawyer',
#  518: 'become',
#  519: 'challenge',
#  520: 'violence',
#  521: 'ceo',
#  522: 'control',
#  523: 'did',
#  524: 'legislation',
#  525: 'strike',
#  526: '6',
#  527: 'use',
#  528: '25',
#  529: 'brazil',
#  530: 'peace',
#  531: 'led',
#  532: 'criticizes',
#  533: 'ireland',
#  534: 'start',
#  535: 'arabia',
#  536: 'makes',
#  537: 'strategy',
#  538: 'rebels',
#  539: 'journalist',
#  540: 'detained',
#  541: 'press',
#  542: 'staff',
#  543: 'working',
#  544: 'progress',
#  545: 'visa',
#  546: 'irish',
#  547: 'pressure',
#  548: 'mugabe',
#  549: 'funds',
#  550: 'nominate',
#  551: 'names',
#  552: 'supporters',
#  553: 'fed',
#  554: 'clear',
#  555: 'elections',
#  556: 'nears',
#  557: 'rubio',
#  558: 'potential',
#  559: 'drop',
#  560: 'now',
#  561: 'freedom',
#  562: 'migrant',
#  563: 'possible',
#  564: 'rally',
#  565: 'harassment',
#  566: 'conservatives',
#  567: 'aim',
#  568: 'seeking',
#  569: 'american',
#  570: 'diplomatic',
#  571: 'passes',
#  572: 'steps',
#  573: 'sue',
#  574: 'protect',
#  575: 'asia',
#  576: 'friday',
#  577: 'probes',
#  578: 'get',
#  579: 'jailed',
#  580: 'tpp',
#  581: 'visits',
#  582: 'leads',
#  583: 'target',
#  584: 'arrests',
#  585: 'sri',
#  586: 'through',
#  587: 'ukraine',
#  588: 'sessions',
#  589: 'europe',
#  590: 'quits',
#  591: 'supports',
#  592: 'other',
#  593: 'delay',
#  594: 'parties',
#  595: 'fraud',
#  596: 'venezuelan',
#  597: 'east',
#  598: 'country',
#  599: 'free',
#  600: 'latest',
#  601: 'jobs',
#  602: 'tuesday',
#  603: 'groups',
#  604: 'abortion',
#  605: 'cruz',
#  606: 'expects',
#  607: 'unlikely',
#  608: 'hit',
#  609: 'situation',
#  610: 'united',
#  611: 'influence',
#  612: 'made',
#  613: 'deadly',
#  614: 'view',
#  615: 'early',
#  616: 'puts',
#  617: 'ousted',
#  618: 'reports',
#  619: 'had',
#  620: 'looms',
#  621: 'chair',
#  622: 'making',
#  623: 'companies',
#  624: 'curb',
#  625: 'fix',
#  626: 'issue',
#  627: 'body',
#  628: 'times',
#  629: 'search',
#  630: 'backed',
#  631: 'flynn',
#  632: 'doubts',
#  633: 'response',
#  634: '000',
#  635: 'boat',
#  636: 'scandal',
#  637: 'critic',
#  638: 'april',
#  639: 'when',
#  640: 'veto',
#  641: 'cites',
#  642: 'remain',
#  643: 'energy',
#  644: 'sex',
#  645: 'members',
#  646: 'many',
#  647: 'consider',
#  648: 'drug',
#  649: 'conflict',
#  650: 'show',
#  651: 'book',
#  652: 'fighters',
#  653: 'workers',
#  654: 'libya',
#  655: 'market',
#  656: 'economy',
#  657: 'victory',
#  658: '3',
#  659: '5',
#  660: 'fund',
#  661: 'woman',
#  662: 'part',
#  663: 'lanka',
#  664: 'avoid',
#  665: 'stay',
#  666: 'ria',
#  667: 'maduro',
#  668: 'lawsuit',
#  669: 'convention',
#  670: 'investigation',
#  671: 'highlights',
#  672: "syria's",
#  673: 'troops',
#  674: "brazil's",
#  675: 'infrastructure',
#  676: 'since',
#  677: 'abe',
#  678: 'ministry',
#  679: 'prince',
#  680: 'turn',
#  681: 'considering',
#  682: 'focus',
#  683: "lebanon's",
#  684: 'based',
#  685: 'pushes',
#  686: 'long',
#  687: 'embassy',
#  688: 'hospital',
#  689: 'allegations',
#  690: 'congressman',
#  691: 'testimony',
#  692: 'australia',
#  693: "iran's",
#  694: 'unity',
#  695: '7',
#  696: 'blocks',
#  697: 'without',
#  698: 'hacked',
#  699: 'consumer',
#  700: 'watchdog',
#  701: 'nyt',
#  702: 'welcomes',
#  703: 'lebanese',
#  704: 'clashes',
#  705: 'chemical',
#  706: 'murder',
#  707: 'action',
#  708: 'row',
#  709: 'controversy',
#  710: 'region',
#  711: 'unveils',
#  712: 'spokesman',
#  713: 'candidates',
#  714: 'credit',
#  715: 'insurance',
#  716: 'taxes',
#  717: 'duterte',
#  718: 'americans',
#  719: '2016',
#  720: 'swiss',
#  721: "iraq's",
#  722: 'chiefs',
#  723: 'mccain',
#  724: 'returns',
#  725: 'illinois',
#  726: 'cambodia',
#  727: 'hungary',
#  728: 'palestinian',
#  729: 'politico',
#  730: 'lavrov',
#  731: 'ambassador',
#  732: 'tell',
#  733: 'canada',
#  734: 'surge',
#  735: 'prime',
#  736: 'civil',
#  737: 'found',
#  738: 'vp',
#  739: 'gulf',
#  740: 'criticism',
#  741: 'position',
#  742: 'shooting',
#  743: 'draft',
#  744: 'crimes',
#  745: 'muslims',
#  746: 'feb',
#  747: 'est',
#  748: 'industry',
#  749: 'water',
#  750: 'concerns',
#  751: 'pledges',
#  752: 'expected',
#  753: 'outside',
#  754: 'sets',
#  755: 'aides',
#  756: 'international',
#  757: 'africa',
#  758: '30',
#  759: 'links',
#  760: 'only',
#  761: 'shift',
#  762: 'toward',
#  763: 'arizona',
#  764: 'declares',
#  765: 'nbc',
#  766: 'give',
#  767: 'child',
#  768: 'eyes',
#  769: 'dialogue',
#  770: 'another',
#  771: 'human',
#  772: 'defend',
#  773: "uk's",
#  774: 'condemns',
#  775: 'emergency',
#  776: 'december',
#  777: 'suspected',
#  778: 'era',
#  779: 'cnbc',
#  780: 'terrorism',
#  781: 'bipartisan',
#  782: 'secret',
#  783: 'school',
#  784: '13',
#  785: 'shutdown',
#  786: 'collapse',
#  787: 'netanyahu',
#  788: 'hurt',
#  789: 'weeks',
#  790: 'zuma',
#  791: 'capital',
#  792: 'countries',
#  793: 'tensions',
#  794: 'university',
#  795: 'romney',
#  796: 'fox',
#  797: 'questions',
#  798: 'colombia',
#  799: 'month',
#  800: 'resume',
#  801: 'due',
#  802: 'laws',
#  803: 'reviewing',
#  804: 'told',
#  805: 'mexican',
#  806: "italy's",
#  807: 'bodies',
#  808: 'global',
#  809: 'finds',
#  810: 'gaza',
#  811: 'building',
#  812: 'missing',
#  813: 'militant',
#  814: 'charged',
#  815: "britain's",
#  816: "turkey's",
#  817: 'assad',
#  818: 'cohn',
#  819: 'pakistani',
#  820: 'leaves',
#  821: 'husband',
#  822: 'risk',
#  823: 'challenges',
#  824: 'beijing',
#  825: 'deals',
#  826: 'commission',
#  827: 'firm',
#  828: 'reach',
#  829: 'ramaphosa',
#  830: 'ministers',
#  831: 'special',
#  832: 'accused',
#  833: 'data',
#  834: 'exit',
#  835: 'need',
#  836: 'half',
#  837: 'process',
#  838: 'peninsula',
#  839: 'kansas',
#  840: 'loses',
#  841: 'keep',
#  842: 'labour',
#  843: 'peru',
#  844: 'do',
#  845: 'find',
#  846: 'reforms',
#  847: 'tests',
#  848: 'cnn',
#  849: 'kenya',
#  850: 'boycott',
#  851: 'mnangagwa',
#  852: 'kushner',
#  853: "'no",
#  854: 'needed',
#  855: 'firms',
#  856: "may's",
#  857: 'intel',
#  858: 'interest',
#  859: 'brussels',
#  860: 'msnbc',
#  861: 'dec',
#  862: 'allow',
#  863: 'june',
#  864: 'commerce',
#  865: '60',
#  866: 'between',
#  867: 'navy',
#  868: 'epa',
#  869: 'concerned',
#  870: 'sexual',
#  871: 'banned',
#  872: 'promises',
#  873: 'choice',
#  874: 'hezbollah',
#  875: 'better',
#  876: '19',
#  877: "governor's",
#  878: 'any',
#  879: 'stocks',
#  880: 'hearing',
#  881: 'they',
#  882: '4',
#  883: 'gmt',
#  884: 'hate',
#  885: 'polish',
#  886: 'zika',
#  887: '24',
#  888: "obama's",
#  889: 'holds',
#  890: 'final',
#  891: 'alleged',
#  892: 'wounded',
#  893: 'accounts',
#  894: '50',
#  895: 'sept',
#  896: 'tusk',
#  897: 'electoral',
#  898: 'decide',
#  899: 'son',
#  900: 'iranian',
#  901: 'left',
#  902: '10',
#  903: 'within',
#  904: 'hillary',
#  905: 'weapons',
#  906: 'curbs',
#  907: 'being',
#  908: '15',
#  909: 'manafort',
#  910: 'ny',
#  911: 'drone',
#  912: 'list',
#  913: 'primary',
#  914: 'delays',
#  915: 'corporate',
#  916: 'proposal',
#  917: 'term',
#  918: 'money',
#  919: 'linked',
#  920: 'southern',
#  921: 'argentina',
#  922: 'second',
#  923: "'dreamers'",
#  924: 'draws',
#  925: 'service',
#  926: 'break',
#  927: 'kenyan',
#  928: 'dies',
#  929: 'temer',
#  930: 'their',
#  931: 'failure',
#  932: 'blast',
#  933: 'regulation',
#  934: 'looks',
#  935: 'light',
#  936: 'request',
#  937: 'third',
#  938: 'raqqa',
#  939: 'costs',
#  940: 'step',
#  941: 'moon',
#  942: 'measures',
#  943: 'system',
#  944: 'fear',
#  945: 'indonesia',
#  946: 'sea',
#  947: 'central',
#  948: 'train',
#  949: 'points',
#  950: 'manager',
#  951: 'kurdistan',
#  952: 'gorsuch',
#  953: 'further',
#  954: 'past',
#  955: 'medicaid',
#  956: 'access',
#  957: 'confirms',
#  958: 'changes',
#  959: 'submarine',
#  960: 'stand',
#  961: 'australian',
#  962: 'remains',
#  963: 'months',
#  964: 'ifax',
#  965: 'accuses',
#  966: 'payments',
#  967: 'raises',
#  968: 'growing',
#  969: 'nsa',
#  970: 'car',
#  971: 'pledge',
#  972: 'short',
#  973: 'safety',
#  974: 'interview',
#  975: 'announces',
#  976: 'released',
#  977: 'operation',
#  978: 'idlib',
#  979: 'cities',
#  980: 'abuse',
#  981: 'inquiry',
#  982: 'include',
#  983: 'weighs',
#  984: 'resolution',
#  985: 'anc',
#  986: 'discussed',
#  987: 'wednesday',
#  988: 'charge',
#  989: 'responsibility',
#  990: 'european',
#  991: 'victims',
#  992: 'taiwan',
#  993: 'millions',
#  994: "'very",
#  995: 'cannot',
#  996: 'zealand',
#  997: 'guilty',
#  998: 'i',
#  999: 'fighting',
#  1000: 'development',
#  ...}

# %%
# Cantidad de palabras en el vocabulario
vocab_size = len(tok.word_counts)
vocab_size
# Out:
# 6159

# %%
# El índice para cada palabra
# El sistema las ordena de las más populares a las menos populares
print(tok.word_index)
# Out:
# {'to': 1, 'u': 2, 'trump': 3, 'in': 4, 's': 5, 'on': 6, 'says': 7, 'of': 8, 'for': 9, 'with': 10, 'house': 11, 'after': 12, 'as': 13, 'over': 14, 'north': 15, 'at': 16, 'white': 17, 'russia': 18, 'new': 19, 'korea': 20, 'from': 21, 'not': 22, 'bill': 23, 'court': 24, 'senate': 25, 'obama': 26, 'clinton': 27, 'republican': 28, 'state': 29, 'china': 30, 'tax': 31, 'will': 32, 'election': 33, "trump's": 34, 'deal': 35, 'and': 36, 'eu': 37, 'by': 38, 'a': 39, 'the': 40, 'vote': 41, 'may': 42, 'be': 43, 'south': 44, 'talks': 45, 'police': 46, 'n': 47, 'minister': 48, 'iran': 49, 'chief': 50, 'congress': 51, 'against': 52, 'factbox': 53, 'pm': 54, 'government': 55, 'president': 56, 'republicans': 57, 'probe': 58, 'leader': 59, 'brexit': 60, 'plan': 61, 'law': 62, 'calls': 63, 'more': 64, 'party': 65, 'syria': 66, 'is': 67, 'top': 68, 'lawmakers': 69, 'up': 70, 'ban': 71, 'no': 72, 'about': 73, 'foreign': 74, 'healthcare': 75, 'saudi': 76, 'nuclear': 77, 'russian': 78, 'myanmar': 79, 'military': 80, 'trade': 81, 'sanctions': 82, 'sources': 83, 'uk': 84, 'presidential': 85, 'opposition': 86, 'has': 87, 'budget': 88, 'attack': 89, 'it': 90, 'could': 91, 'security': 92, 'urges': 93, 'reform': 94, 'border': 95, 'two': 96, 'media': 97, 'senator': 98, 'aid': 99, 'rights': 100, 'rohingya': 101, 'former': 102, 'official': 103, 'ex': 104, 'putin': 105, 'german': 106, 'out': 107, 'islamic': 108, 'but': 109, 'turkey': 110, 'say': 111, 'campaign': 112, 'he': 113, 'supreme': 114, 'panel': 115, 'meet': 116, 'anti': 117, 'obamacare': 118, 'korean': 119, 'visit': 120, 'if': 121, 'governor': 122, 'catalan': 123, 'travel': 124, 'coalition': 125, 'mexico': 126, 'democratic': 127, 'would': 128, 'under': 129, 'tells': 130, 'his': 131, 'democrats': 132, 'killed': 133, 'france': 134, 'end': 135, 'exclusive': 136, 'race': 137, 'first': 138, 'meeting': 139, 'discuss': 140, 'into': 141, 'officials': 142, 'ahead': 143, 'fight': 144, 'seek': 145, 'should': 146, 'independence': 147, 'crisis': 148, 'ruling': 149, 'that': 150, 'parliament': 151, 'support': 152, 'general': 153, 'tillerson': 154, 'attacks': 155, 'pick': 156, 'bid': 157, 'wants': 158, 'syrian': 159, 'lead': 160, 'next': 161, 'back': 162, 'seeks': 163, 'debate': 164, 'puerto': 165, 'poll': 166, 'war': 167, 'policy': 168, 'immigration': 169, 'group': 170, 'turkish': 171, 'speaker': 172, 'report': 173, 'missile': 174, 'britain': 175, 'fbi': 176, 'help': 177, 'post': 178, 'ties': 179, 'climate': 180, 'before': 181, 'iraq': 182, 'jerusalem': 183, 'cut': 184, 'leaders': 185, 'week': 186, 'call': 187, 'department': 188, 'army': 189, 'backs': 190, 'ryan': 191, 'key': 192, 'million': 193, 'rico': 194, 'off': 195, 'its': 196, 'judge': 197, 'source': 198, 'air': 199, 'agency': 200, 'senators': 201, 'states': 202, 'have': 203, 'adviser': 204, 'amid': 205, 'reuters': 206, 'nominee': 207, 'win': 208, 'washington': 209, 'attorney': 210, 'corruption': 211, 'xi': 212, 'french': 213, 'defense': 214, 'administration': 215, 'threat': 216, 'twitter': 217, 'order': 218, 'sees': 219, 'right': 220, 'california': 221, 'want': 222, 'national': 223, 'down': 224, 'billion': 225, 'warns': 226, 'secretary': 227, 'aide': 228, 'kremlin': 229, 'business': 230, 'hacking': 231, 'rules': 232, 'three': 233, 'israel': 234, 'who': 235, 'push': 236, 'must': 237, "china's": 238, 'macron': 239, 'decision': 240, 'takes': 241, 'chinese': 242, 'make': 243, 'one': 244, "russia's": 245, 'arrested': 246, 'pentagon': 247, 'hopes': 248, 'oil': 249, 'catalonia': 250, 'intelligence': 251, 'kills': 252, 'case': 253, 'pence': 254, '1': 255, 'approves': 256, 'some': 257, 'transgender': 258, 'sanders': 259, 'health': 260, 'political': 261, 'japan': 262, 'still': 263, 'than': 264, 'germany': 265, 'merkel': 266, 'near': 267, 'orders': 268, 'see': 269, 'year': 270, 'refugees': 271, 'militants': 272, 'plans': 273, 're': 274, 'head': 275, 'candidate': 276, '2018': 277, 'lebanon': 278, 'hurricane': 279, 'does': 280, 'vows': 281, 'work': 282, 'release': 283, 're ...

# %%
# Cantidad de veces quea aparece cada palabra en cada "documento"
# (1 documento = 1 caso de entrada)
print(tok.word_docs)
# Out:
# defaultdict(<class 'int'>, {'safety': 5, 'but': 34, 'go': 12, 'says': 439, 'home': 11, 'to': 1002, 'rohingyas': 2, 'bangladesh': 13, 'must': 18, 'budget': 39, 'controversial': 4, 'float': 2, 'republicans': 54, 'plan': 50, 'house': 198, 'stance': 10, 'pence': 17, 'it': 38, 'france': 29, 'eu': 79, "trump's": 87, 'on': 463, 'clarify': 4, 'wants': 26, 'head': 16, 'consumer': 7, 'over': 149, 's': 598, 'trump': 654, 'in': 638, 'battle': 12, 'watchdog': 7, 'u': 648, 'court': 101, 'backs': 22, 'interim': 1, 'nyt': 7, 'ryan': 22, 'expects': 8, 'tax': 85, 'this': 14, 'fall': 3, 'speaker': 24, 'interview': 5, 'with': 210, 'referendum': 13, '1': 16, 'independence': 25, 'proceed': 4, 'will': 91, 'catalan': 31, 'oct': 2, 'leader': 52, 'healthcare': 44, 'announces': 5, 'picks': 12, 'posts': 3, 'key': 22, 'factbox': 58, 'two': 36, 'fill': 2, 'sharif': 3, 'pm': 58, 'nawaz': 1, 'ex': 35, 'calls': 48, 'newly': 2, "'traitor'": 1, 'freed': 4, 'a': 74, 'pakistani': 6, 'islamist': 12, 'xi': 20, 'end': 29, 'and': 83, 'opioid': 3, 'he': 33, 'try': 2, "china's": 18, 'crisis': 27, 'salary': 1, 'guatemala': 3, 'not': 105, 'bonus': 1, 'probe': 53, "president's": 4, 'supreme': 33, 'leaves': 6, 'report': 24, 'clinton': 95, 'husband': 6, 'abedin': 1, 'sexting': 1, 'after': 166, 'weiner': 2, 'aide': 19, 'discuss': 28, 'north': 128, 'putin': 35, "korea's": 11, 'launch': 13, 'kremlin': 19, 'missile': 24, 'macron': 18, 'grid': 2, 'all': 14, 'candidate': 16, 'chile': 3, 'conservative': 12, 'for': 381, 'renewable': 2, 'presidential': 41, 'decision': 18, 'strategy': 9, 'afghanistan': 12, 'no': 45, 'makes': 9, 'insult': 1, "kim's": 1, "what's": 2, 'anyway': 1, "'dotard'": 1, 'insurer': 2, '2018': 16, 'at': 123, 'risk': 6, 'hundreds': 4, 'obamacare': 32, 'of': 409, 'counties': 1, 'ban': 46, 'kuwait': 3, 'challenges': 6, 'travel': 31, 'israeli': 12, 'air': 20, 'german': 35, 'ruling': 27, 'committee': 13, 'constitution': 3, 'welcomes': 7, 'syrian': 24, 'government': 58, 'obama': 99, 'about': 45, 'expectations': 1, 'deal': 86, 'cautious': 4, 'syria': 47, 'agency': 21, 'news': 13, 'saudi': 44, 'lebanese': 7, 'kidnapped': 3, 'lebanon': 16, 'released': 5, 'serious': 4, 'turkey': 34, 'operation': 5, 'idlib': 5, 'rebels': 9, 'bank': 14, 'gps': 1, 'panel': 33, 'reached': 1, 'records': 1, 'agreement': 2, 'fusion': 1, 'million': 21, 'restore': 3, 'yemeni': 4, '150': 1, 'cities': 5, 'services': 10, 'world': 12, 'approves': 17, 'claims': 10, 'kindergarten': 1, 'some': 17, 'beijing': 6, 'unfounded': 1, 'abuse': 5, 'say': 34, 'china': 88, 'police': 66, 'is': 47, 'dispute': 10, 'experts': 11, 'assertion': 1, 'that': 27, 'capability': 1, 'nuclear': 44, 'lagging': 1, 'arms': 12, 'rosy': 1, 'forecast': 2, 'independent': 4, 'analysis': 3, 'clashes': 7, 'cut': 23, 'white': 120, 'nieto': 2, 'deals': 6, 'meet': 33, 'big': 12, 'pena': 2, 'unlikely': 8, 'mexico': 30, 'lead': 26, 'new': 110, 'defends': 11, 'role': 12, 'commission': 6, 'voting': 10, 'democrat': 15, 'hampshire': 2, 'n': 64, 'chemical': 7, 'denies': 14, 'attack': 40, 'pakistan': 14, 'india': 13, 'by': 78, 'spy': 11, 'hit': 8, 'malware': 1, 'exclusive': 29, 'cybersecurity': 1, 'firm': 6, 'journalist': 9, 'leaders': 23, 'inquiry': 5, 'full': 4, 'malta': 2, 'urge': 13, 'murder': 7, 'into': 28, 'russian': 43, 'kerimov': 2, 'detained': 9, 'businessman': 3, "prosecutor's": 2, 'french': 20, 'nice': 1, 'office': 12, 'federal': 11, 'next': 26, 'week': 23, 'vote': 74, 'include': 5, 'rapper': 1, 'founder': 1, 'meetings': 4, 'west': 10, 'microsoft': 1, 'kanye': 1, 'bill': 104, 'gates': 2, 'action': 7, 'immigrants': 4, 'limbo': 2, 'top': 47, 'weighs': 5, 'as': 159, 'resolution': 5, 'reach': 6, 'senators': 21, 'corker': 4, 'toomey': 1, 'republican': 95, 'ramaphosa': 6, 'race': 28, 'media': 36, 'science': 3, 'female': 2, "africa's": 10, 'anc': 5, 'deputy': 10, 'minister': 64, 'south': 69, 'democratic': 30, 'blaming': 1, 'schumer': 3, 'stop': 13, 'ricans': 2, 'puerto': 25, 'senator': 36, 'ministers': 6, 'situation': 8, 'foreign': 44, 'discussed ...

# %% [markdown]
# ### Definir el modelo

# %%
model = Sequential()

# la primera capa es de embedding entrenable. Recordar que se puede variar el tamaño
# del embedding a entrenar
model.add(Embedding(input_dim=vocab_size+1, output_dim=50, input_shape=(None,)))

model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.2))
# model.add(Dense(32, activation='relu'))

# Predicción de clasificación con softmax
# La salida es del tamaño del vocabulario
model.add(Dense(vocab_size+1, activation='softmax'))


# Clasificación multiple categórica --> loss = categorical_crossentropy
# notar que usamos la versión Sparse para utilizar sólo índices en lugar de OHE
model.compile(loss=SparseCategoricalCrossentropy(), optimizer='rmsprop')

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, None, 50)            │         308,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, None, 100)           │          60,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, None, 100)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, None, 100)           │          80,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, None, 100)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, None, 6160)          │         622,160 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,070,960 (4.09 MB)
#  Trainable params: 1,070,960 (4.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Dado que por el momento no hay implementaciones adecuadas de la perplejidad que puedan operar en tiempo de entrenamiento, armaremos un Callback *ad-hoc* que la calcule en cada epoch.
#
# **Nota**: un Callback es una rutina gatillada por algún evento, son muy útiles para relevar datos en diferentes momentos del desarrollo del modelo. En este caso queremos hacer un cálculo cada vez que termina una epoch de entrenamiento.

# %%
class PplCallback(keras.callbacks.Callback):
    '''
    Este callback es una solución ad-hoc para calcular al final de cada epoch de
    entrenamiento la métrica de Perplejidad sobre un conjunto de datos de validación.
    La perplejidad es una métrica cuantitativa para evaluar la calidad de la generación de secuencias.
    Además implementa la finalización del entrenamiento (Early Stopping)
    si la perplejidad no mejora después de `patience` epochs.
    '''

    def __init__(self, val_data, history_ppl, patience=5):
        self.val_data = val_data
        self.history_ppl = history_ppl
        self.patience = patience
        self.target = []
        self.padded = []
        count = 0
        self.info = []
        self.min_score = np.inf
        self.patience_counter = 0
        for seq in self.val_data:
            len_seq = len(seq)
            subseq = [seq[:i] for i in range(len_seq)]
            self.target.extend([seq[i] for i in range(len_seq)])
            if len(subseq) != 0:
                self.padded.append(pad_sequences(subseq, maxlen=max_context_size + 1, padding='pre'))
                self.info.append((count, count + len_seq))
                count += len_seq
        self.padded = np.vstack(self.padded)

    def on_epoch_end(self, epoch, logs=None):
        scores = []
        predictions = self.model.predict(self.padded, verbose=0)
        for start, end in self.info:
            probs = [predictions[idx_seq, -1, idx_vocab] for idx_seq, idx_vocab in zip(range(start, end), self.target[start:end])]
            scores.append(np.exp(-np.sum(np.log(probs)) / (end - start)))
        current_score = np.mean(scores)
        self.history_ppl.append(current_score)
        print(f'\nMean perplexity: {current_score:.4f}\n')
        if current_score < self.min_score:
            self.min_score = current_score
            model_filename = f"my_model_{epoch + 1}_{current_score:.4f}.h5"
            self.model.save(model_filename)
            print(f"Saved new model as {model_filename}!")
            self.patience_counter = 0
        else:
            self.patience_counter += 1
            if self.patience_counter == self.patience:
                print("Stopping training...")
                self.model.stop_training = True

# %% [markdown]
# ### Entrenamiento

# %%
# fiteamos, nótese el agregado del callback con su inicialización. El batch_size lo podemos seleccionar a mano
# en general, lo mejor es escoger el batch más grande posible que minimice el tiempo de cada época.
# En la variable `history_ppl` se guardarán los valores de perplejidad para cada época.
history_ppl = []
hist = model.fit(X, y, epochs=20, callbacks=[PplCallback(tokenized_sentences_val, history_ppl)], batch_size=64)
# Out:
# Epoch 1/20
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - loss: 5.7486
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Mean perplexity: 2287.3355
#
# Saved new model as my_model_1_2287.3355.h5!
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 220s 339ms/step - loss: 5.7475
# Epoch 2/20
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - loss: 4.6364
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Mean perplexity: 2208.9635
#
# Saved new model as my_model_2_2208.9635.h5!
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 246s 315ms/step - loss: 4.6364
# Epoch 3/20
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - loss: 4.5649
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Mean perplexity: 2187.4695
#
# Saved new model as my_model_3_2187.4695.h5!
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 183s 297ms/step - loss: 4.5649
# Epoch 4/20
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - loss: 4.4704
# Mean perplexity: 2472.7037
#
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 216s 319ms/step - loss: 4.4704
# Epoch 5/20
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - loss: 4.3807
# Mean perplexity: 2474.0162
#
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 202s 320ms/step - loss: 4.3807
# Epoch 6/20
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 4.3152
# Mean perplexity: 2239.1034
#
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 188s 305ms/step - loss: 4.3152
# Epoch 7/20
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - loss: 4.2744
# Mean perplexity: 2246.1405
#
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 198s 320ms/step - loss: 4.2744
# Epoch 8/20
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 4.2390
# Mean perplexity: 2400.3334
#
# Stopping training...
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 170s 275ms/step - loss: 4.2390

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Podemos graficar la evolución de la perplejidad con las épocas.
# Recordar que el valor de perplejidad del modelo trivial es el tamaño del vocabulario.
epoch_count = range(1, len(history_ppl) + 1)

plt.figure(figsize=(10, 6))
sns.lineplot(x=epoch_count, y=history_ppl, marker='o')
plt.title('Evolución de la Perplejidad durante el Entrenamiento')
plt.xlabel('Época')
plt.ylabel('Perplejidad')
plt.grid(True)
plt.show()

# %%
import glob

model_files = glob.glob('my_model_*.h5')
if model_files:
    # Ordena los archivos por el valor de perplejidad en el nombre
    model_files.sort(key=lambda x: float(x.split('_')[-1].replace('.h5', '')))
    best_model_file = model_files[-1]  # El archivo con la menor perplejidad
    print(f'Cargando el mejor modelo: {best_model_file}')
    model = keras.models.load_model(best_model_file)
else:
    print("No se encontraron archivos de modelo.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Cargando el mejor modelo: my_model_1_46420.1362.h5

# %%
# # Cargamos el mejor modelo guardado del entrenamiento para hacer inferencia
# model = keras.models.load_model('my_model')

# %% [markdown]
# ### Predicción de próxima palabra

# %%
# Se puede usar gradio para probar el modelo
# Gradio es una herramienta muy útil para crear interfaces para ensayar modelos
# https://gradio.app/

# !pip install -q gradio

# %%
import gradio as gr

def model_response(human_text):

    # Encodeamos
    encoded = tok.texts_to_sequences([human_text])[0]
    # Si tienen distinto largo
    encoded = pad_sequences([encoded], maxlen=max_context_size, padding='pre')

    # Predicción softmax
    y_hat = np.argmax(model.predict(encoded)[0,-1,:])


    # Debemos buscar en el vocabulario la palabra
    # que corresopnde al indice (y_hat) predicho por le modelo
    out_word = ''
    for word, index in tok.word_index.items():
        if index == y_hat:
            out_word = word
            break

    # Agrego la palabra a la frase predicha
    return human_text + ' ' + out_word

iface = gr.Interface(
    fn=model_response,
    inputs=["textbox"],
    outputs="text")

iface.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://853151ae4bd7533745.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://853151ae4bd7533745.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://853151ae4bd7533745.gradio.live

# %% [markdown]
# ### Generación de secuencias

# %%
def generate_seq(model, tokenizer, seed_text, max_length, n_words):
    """
        Exec model sequence prediction

        Args:
            model (keras): modelo entrenado
            tokenizer (keras tokenizer): tonenizer utilizado en el preprocesamiento
            seed_text (string): texto de entrada (input_seq)
            max_length (int): máxima longitud de la sequencia de entrada
            n_words (int): números de palabras a agregar a la sequencia de entrada
        returns:
            output_text (string): sentencia con las "n_words" agregadas
    """
    output_text = seed_text
	  # generate a fixed number of words
    for _ in range(n_words):
		  # Tokenizamos
      encoded = tokenizer.texts_to_sequences([output_text])[0]

		  # Si tienen distinto largo
      encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')

		  # Predicción softmax
      y_hat = np.argmax(model.predict(encoded)[0,-1,:])

      # Vamos concatenando las predicciones
      out_word = ''

      # Debemos buscar en el vocabulario la palabra
      # que corresopnde al indice (y_hat) predicho por le modelo
      for word, index in tokenizer.word_index.items():
        if index == y_hat:
          out_word = word
          break

		  # Agrego las palabras a la frase predicha
      output_text += ' ' + out_word

    return output_text

# %%
input_text='donald trump\'t'

generate_seq(model, tok, input_text, max_length=max_context_size, n_words=10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# "donald trump't kills to trump s trump s trump s trump s"

# %% [markdown]
# ###  Beam search y muestreo aleatorio

# %%
# funcionalidades para hacer encoding y decoding

def encode(text,max_length=max_context_size):

    encoded = tok.texts_to_sequences([text])[0]
    encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')

    return encoded

def decode(seq):
    return tok.sequences_to_texts([seq])

# %%
from scipy.special import softmax

# función que selecciona candidatos para el beam search
def select_candidates(pred,num_beams,vocab_size,history_probs,history_tokens,temp,mode):

  # colectar todas las probabilidades para la siguiente búsqueda
  pred_large = []

  for idx,pp in enumerate(pred):
    pred_large.extend(np.log(pp+1E-10)+history_probs[idx])

  pred_large = np.array(pred_large)

  # criterio de selección
  if mode == 'det':
    idx_select = np.argsort(pred_large)[::-1][:num_beams] # beam search determinista
  elif mode == 'sto':
    idx_select = np.random.choice(np.arange(pred_large.shape[0]), num_beams, p=softmax(pred_large/temp)) # beam search con muestreo aleatorio
  else:
    raise ValueError(f'Wrong selection mode. {mode} was given. det and sto are supported.')

  # traducir a índices de token en el vocabulario
  new_history_tokens = np.concatenate((np.array(history_tokens)[idx_select//vocab_size],
                        np.array([idx_select%vocab_size]).T),
                      axis=1)

  # devolver el producto de las probabilidades (log) y la secuencia de tokens seleccionados
  return pred_large[idx_select.astype(int)], new_history_tokens.astype(int)


def beam_search(model,num_beams,num_words,input,temp=1,mode='det'):

    # first iteration

    # encode
    encoded = encode(input)

    # first prediction
    y_hat = model.predict(encoded,verbose=0)[0,-1,:]

    # get vocabulary size
    vocab_size = y_hat.shape[0]

    # initialize history
    history_probs = [0]*num_beams
    history_tokens = [encoded[0]]*num_beams

    # select num_beams candidates
    history_probs, history_tokens = select_candidates([y_hat],
                                        num_beams,
                                        vocab_size,
                                        history_probs,
                                        history_tokens,
                                        temp,
                                        mode)

    # beam search loop
    for i in range(num_words-1):

      preds = []

      for hist in history_tokens:

        # actualizar secuencia de tokens
        input_update = np.array([hist[i+1:]]).copy()

        # predicción
        y_hat = model.predict(input_update,verbose=0)[0,-1,:]

        preds.append(y_hat)

      history_probs, history_tokens = select_candidates(preds,
                                                        num_beams,
                                                        vocab_size,
                                                        history_probs,
                                                        history_tokens,
                                                        temp,
                                                        mode)

    return history_tokens

# %%
# predicción con beam search.
# Se pueden camiar los modos entre 'det' (determinista) y
# 'sto' (estocástico)
# para el caso estocástico también se puede variar la temperatura
salidas = beam_search(model,num_beams=10,num_words=6,input="donald trump says about russia",temp=1,mode='sto')

# %%
# tenemos `num_beams` salidas ordenadas de mayor a menor likelihood
salidas.shape
# Out:
# (10, 15)

# %%
# veamos las salidas
decode(salidas[0])
# Out:
# ['donald trump says about russia at at at at says the']
